# %% [markdown]
# # So overall, this is the same as the binary classifier from the first binary classifier, except we also have shorting as well

# %% [markdown]
# In this case, we would be executing  trades risking 2% in total of our capital when to buy and when to short. That way we will also make sure not to loose our total capital in general, and we will also simulate liquidation. Meaning, any other stuff that was updated in the first binary classifier we go over and put it in this classifier as well
#
# **Rules:**
# -Preprocess the data
# -Define model architecture
# -Train the model and feed the data to it
# -F1-Score & Backtesting
#
# **Live simulation---**
# Best to do 50 iterations for all tests in general, look at your python script on your desktop to execute, load, and run them all, after cleaning what needs to be done. Mind you any metatrader5 data we are fetching is being simulated here, nothign is being reflected within our account.

# %%
#making sure we train with our GPU, Pytorch is the fucking shit!!!
import torch
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device(0)

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA TITAN RTX'

# %%
import pandas as pd
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
import os
import warnings

# Set multiprocessing method
torch.multiprocessing.set_start_method('spawn', force=True)

# Suppress warnings for cleaner output
warnings.filterwarnings("ignore")

# Custom Dataset class with exception handling
class BitcoinDataset(Dataset):
    def __init__(self, features, labels):
        self.features = torch.tensor(features, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self, idx):
        try:
            features = self.features[idx]
            label = self.labels[idx]
            return features, label
        except Exception as e:
            print(f"Error loading data at index {idx}: {e}")
            return torch.tensor([]), torch.tensor([])  # Return empty tensors on error

# Load the preprocessed data
data_paths = {
    'minute11': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/minute1_trained.csv',
    'minute1_22': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_2.csv',
    'minute1_33': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_3.csv',
    'minute1_44': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_4.csv',
    'minute1_555': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_5.csv',
    'minute1_66': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_6.csv',
    'minute1_77': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_7.csv',
    'minute55': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/minute5_trained.csv',
    'minute155': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/minute15_trained.csv',
    'minute300': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/minute30_trained.csv',
    'minute301': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_8.csv',
    'minute302': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_9.csv',
    'minute303': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_10.csv',
    'minute304': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_11.csv',
    'minute305': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_12.csv',
    'minute306': 'C:/Users/gunne/OneDrive/Desktop/bitcoin/profit005/bitcoinm1_13.csv'
}

# Function to load and concatenate datasets
def load_data(data_paths):
    data_frames = []
    for key, path in data_paths.items():
        df = pd.read_csv(path, dtype={'DateTime': str})  # Specify dtype for 'DateTime' column
        df['DateTime'] = pd.to_datetime(df['DateTime'], errors='coerce')  # Convert 'DateTime' to datetime
        df = df.set_index('DateTime')
        data_frames.append(df)
    combined_data = pd.concat(data_frames, axis=0)
    return combined_data

# Load and combine datasets
combined_data = load_data(data_paths)

# Debug: print the shape of the combined data
print(f"Combined data shape: {combined_data.shape}")

# Debug: check for NaNs in the data
nan_info = combined_data.isna().sum()
print("NaN values in each column:\n", nan_info)

# Drop columns that are completely NaN or have excessive NaNs
combined_data.drop(columns=['Unnamed: 13', 'Unnamed: 14'], inplace=True)

# Fill NaNs in 'Profit_Between_Time_Series' with a default value (e.g., 0)
combined_data['Profit_Between_Time_Series'].fillna(0, inplace=True)

# Ensure there are no NaNs in the features and labels before splitting
assert not combined_data.isna().any().any(), "Data contains NaNs before splitting"

# Separate features and labels
features = combined_data.drop(columns=['Buy_Signal', 'Sell_Signal']).values
buy_labels = combined_data['Buy_Signal'].values
sell_labels = combined_data['Sell_Signal'].values

# Check for NaNs in features and labels before splitting
assert not np.isnan(features).any(), "Features contain NaNs before splitting"
assert not np.isnan(buy_labels).any(), "Buy labels contain NaNs before splitting"
assert not np.isnan(sell_labels).any(), "Sell labels contain NaNs before splitting"

# Debug: print the shapes of features and labels
print(f"Features shape: {features.shape}, Buy labels shape: {buy_labels.shape}, Sell labels shape: {sell_labels.shape}")

# Split the data
train_features, test_features, train_buy_labels, test_buy_labels, train_sell_labels, test_sell_labels = train_test_split(
    features, buy_labels, sell_labels, test_size=0.2, shuffle=False)
train_features, val_features, train_buy_labels, val_buy_labels, train_sell_labels, val_sell_labels = train_test_split(
    train_features, train_buy_labels, train_sell_labels, test_size=0.2, shuffle=False)

# Standardize the data
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)
val_features = scaler.transform(val_features)
test_features = scaler.transform(test_features)

# Check for NaNs in standardized features
assert not np.isnan(train_features).any(), "Train features contain NaNs after standardization"
assert not np.isnan(val_features).any(), "Validation features contain NaNs after standardization"
assert not np.isnan(test_features).any(), "Test features contain NaNs after standardization"

# Check data for NaNs and infinities
def check_data_for_nans(features, labels):
    if np.isnan(features).any() or np.isnan(labels).any():
        raise ValueError("Data contains NaNs")
    if np.isinf(features).any() or np.isinf(labels).any():
        raise ValueError("Data contains infinite values")

# Check training and validation data
check_data_for_nans(train_features, train_buy_labels)
check_data_for_nans(val_features, val_buy_labels)

# Create DataLoader function with conditional persistent_workers
def create_dataloader(features, labels, batch_size=2048, shuffle=True, num_workers=0):
    dataset = BitcoinDataset(features, labels)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers, pin_memory=True,
                            persistent_workers=num_workers > 0)
    return dataloader

# Define batch_size
batch_size = 2048  # Adjust to fit GPU memory

# Create DataLoaders for buy signals
train_buy_loader = create_dataloader(train_features, train_buy_labels, batch_size, num_workers=0)
val_buy_loader = create_dataloader(val_features, val_buy_labels, batch_size, num_workers=0)
test_buy_loader = create_dataloader(test_features, test_buy_labels, batch_size, num_workers=0)

# Create DataLoaders for sell signals
train_sell_loader = create_dataloader(train_features, train_sell_labels, batch_size, num_workers=0)
val_sell_loader = create_dataloader(val_features, val_sell_labels, batch_size, num_workers=0)
test_sell_loader = create_dataloader(test_features, test_sell_labels, batch_size, num_workers=0)

print("Data Loaders created successfully!")

# Set the device for training (GPU if available, otherwise CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')
# Out:
# Combined data shape: (3626370, 14)
# NaN values in each column:
#  OPEN                                0
# HIGH                                0
# LOW                                 0
# CLOSE                               0
# TICKVOL                             0
# VOL                                 0
# SPREAD                              0
# Change_Open_Close                   0
# Change_High_Low                     0
# Profit_Between_Time_Series          1
# Buy_Signal                          0
# Sell_Signal                         0
# Unnamed: 13                   3626370
# Unnamed: 14                   3626369
# dtype: int64
# Features shape: (3626370, 10), Buy labels shape: (3626370,), Sell labels shape: (3626370,)
# Data Loaders created successfully!
# Using device: cuda

# %%
import torch.nn as nn
import torch.optim as optim
import torch

# Define the RNN model with batch normalization and 15 activation layers
class BitcoinPriceLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
        super(BitcoinPriceLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, hidden_size)
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.fc6 = nn.Linear(hidden_size, hidden_size)
        self.fc7 = nn.Linear(hidden_size, hidden_size)
        self.fc8 = nn.Linear(hidden_size, hidden_size)
        self.fc9 = nn.Linear(hidden_size, hidden_size)
        self.fc10 = nn.Linear(hidden_size, hidden_size)
        self.fc11 = nn.Linear(hidden_size, hidden_size)
        self.fc12 = nn.Linear(hidden_size, hidden_size)
        self.fc13 = nn.Linear(hidden_size, hidden_size)
        self.fc14 = nn.Linear(hidden_size, hidden_size)
        self.fc15 = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out[:, -1, :])
        out = torch.relu(self.fc1(out))
        out = torch.relu(self.fc2(out))
        out = torch.relu(self.fc3(out))
        out = torch.relu(self.fc4(out))
        out = torch.relu(self.fc5(out))
        out = torch.relu(self.fc6(out))
        out = torch.relu(self.fc7(out))
        out = torch.relu(self.fc8(out))
        out = torch.relu(self.fc9(out))
        out = torch.relu(self.fc10(out))
        out = torch.relu(self.fc11(out))
        out = torch.relu(self.fc12(out))
        out = torch.relu(self.fc13(out))
        out = torch.relu(self.fc14(out))
        out = self.fc15(out)
        return out

# Model parameters
input_size = combined_data.shape[1] - 2  # Number of features (exclude 'Buy_Signal' and 'Sell_Signal')
hidden_size = 1024  # Adjust hidden size
num_layers = 8  # Number of LSTM layers
output_size = 2  # Binary classification (buy and sell signals)

# Check if CUDA is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("CUDA is available. Using GPU.")
    print(f"Device name: {torch.cuda.get_device_name(0)}")
else:
    device = torch.device("cpu")
    print("CUDA is not available. Using CPU.")

# Initialize the model, loss function, and optimizer
model = BitcoinPriceLSTM(input_size, hidden_size, num_layers, output_size, dropout=0.5).to(device)

# Initialize weights
def init_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.LSTM):
        for name, param in m.named_parameters():
            if 'weight_ih' in name or 'weight_hh' in name:
                nn.init.xavier_uniform_(param.data)
            elif 'bias' in name:
                nn.init.constant_(param.data, 0)

model.apply(init_weights)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)  # Reduced learning rate and increased L2 regularization
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)

print("Model, loss function, and optimizer created successfully!")
# Out:
# CUDA is available. Using GPU.
# Device name: NVIDIA TITAN RTX
# Model, loss function, and optimizer created successfully!

# %%
# Function to count the number of parameters in a model
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Print the number of parameters in the model
num_params = count_parameters(model)
print(f'The model has {num_params:,} trainable parameters')
# Out:
# The model has 77,717,506 trainable parameters

# %%
#Make sure we are training fully on our GPU

# %%
from torch.cuda.amp import GradScaler, autocast
from tqdm import tqdm
import time
import matplotlib.pyplot as plt

# Ensure the model is moved to the GPU
model = model.to(device)

# Training function with early stopping
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs=100, patience=10):
    scaler = GradScaler()
    train_losses = []
    val_losses = []
    best_val_loss = float('inf')
    patience_counter = 0
    
    for epoch in range(num_epochs):
        start_time = time.time()
        model.train()
        running_loss = 0.0
        
        for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}", unit="batch"):
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            optimizer.zero_grad()
            
            with autocast():
                outputs = model(inputs.unsqueeze(1))  # Add batch dimension for LSTM
                loss = criterion(outputs, labels)
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            
            running_loss += loss.item() * inputs.size(0)
        
        epoch_loss = running_loss / len(train_loader.dataset)
        val_loss = validate_model(model, val_loader, criterion)
        
        train_losses.append(epoch_loss)
        val_losses.append(val_loss)
        
        scheduler.step(val_loss)
        
        epoch_time = time.time() - start_time
        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, Time: {epoch_time:.2f}s")
    
    return train_losses, val_losses

# Validation function
def validate_model(model, val_loader, criterion):
    model.eval()
    running_loss = 0.0
    
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            with autocast():
                outputs = model(inputs.unsqueeze(1))  # Add batch dimension for LSTM
                loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)
    
    val_loss = running_loss / len(val_loader.dataset)
    return val_loss

# Plot loss function
def plot_losses(train_losses, val_losses):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Training and Validation Loss over Epochs')
    plt.show()

# Number of epochs for training
num_epochs = 55

# Train the model and get the losses
train_losses, val_losses = train_model(model, train_buy_loader, val_buy_loader, criterion, optimizer, scheduler, num_epochs, patience=10)

# Plot the losses
plot_losses(train_losses, val_losses)
# Out:
# Epoch 1/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:12<00:00, 15.62batch/s]
# Epoch 1/55, Loss: 0.1408, Val Loss: 0.0556, Time: 83.67s
# Epoch 2/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:13<00:00, 15.53batch/s]
# Epoch 2/55, Loss: 0.0851, Val Loss: 0.0389, Time: 84.19s
# Epoch 3/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:12<00:00, 15.69batch/s]
# Epoch 3/55, Loss: 0.0827, Val Loss: 0.0386, Time: 82.28s
# Epoch 4/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:12<00:00, 15.56batch/s]
# Epoch 4/55, Loss: 0.0812, Val Loss: 0.0469, Time: 83.74s
# Epoch 5/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:12<00:00, 15.58batch/s]
# Epoch 5/55, Loss: 0.0787, Val Loss: 0.0275, Time: 83.51s
# Epoch 6/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:13<00:00, 15.47batch/s]
# Epoch 6/55, Loss: 0.0544, Val Loss: 0.0090, Time: 83.31s
# Epoch 7/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:12<00:00, 15.56batch/s]
# Epoch 7/55, Loss: 0.0400, Val Loss: 0.0069, Time: 83.43s
# Epoch 8/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:13<00:00, 15.46batch/s]
# Epoch 8/55, Loss: 0.0358, Val Loss: 0.0061, Time: 83.75s
# Epoch 9/55: 100%|███████████████████████████████████████████████████████████████| 1134/1134 [01:13<00:00, 15.49batch/s]
# Epoch 9/55, Loss: 0.0329, Val Loss: 0.0045, Time: 84.09s
# Epoch 10/55: 100%|██████████████████████████████████████████████████████████████| 1134/1134 [01:12<00:00, 15.54batch/s]
# Epoch 10/55, Loss: 0.0312, Val Loss: 0.0050, Time: 83.31s
# Epoch 11/55:  98%|████████████████████████████████████████████████████████████▌ | 1107/1134 [01:11<00:01, 15.54batch/s]

# %%
#F1 Score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns

def evaluate_model(model, test_loader, criterion):
    model.eval()
    running_loss = 0.0
    all_labels = []
    all_preds = []
    
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            outputs = model(inputs.unsqueeze(1))  # Add batch dimension for LSTM
            loss = criterion(outputs, labels)
            running_loss += loss.item() * inputs.size(0)
            
            _, preds = torch.max(outputs, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
    
    test_loss = running_loss / len(test_loader.dataset)
    print(f'Test Loss: {test_loss:.4f}')
    
    return all_labels, all_preds

# Evaluate on test_buy_loader or test_sell_loader depending on your focus
all_labels, all_preds = evaluate_model(model, test_buy_loader, criterion)

# Calculate metrics
accuracy = accuracy_score(all_labels, all_preds)
precision = precision_score(all_labels, all_preds)
recall = recall_score(all_labels, all_preds)
f1 = f1_score(all_labels, all_preds)

print(f'Accuracy: {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')

# Plot confusion matrix
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Test Loss: 0.0051
# Accuracy: 0.9989
# Precision: 0.9997
# Recall: 0.9945
# F1 Score: 0.9971

# %%
#Save the model:
import torch

# Save the entire model
torch.save(model, '005_1model.pth')

# %%
# Save the model
torch.save(model.state_dict(), '005_1model.pth')
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score

# Define the RNN model with batch normalization and 15 activation layers
class BitcoinPriceLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
        super(BitcoinPriceLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, hidden_size)
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.fc6 = nn.Linear(hidden_size, hidden_size)
        self.fc7 = nn.Linear(hidden_size, hidden_size)
        self.fc8 = nn.Linear(hidden_size, hidden_size)
        self.fc9 = nn.Linear(hidden_size, hidden_size)
        self.fc10 = nn.Linear(hidden_size, hidden_size)
        self.fc11 = nn.Linear(hidden_size, hidden_size)
        self.fc12 = nn.Linear(hidden_size, hidden_size)
        self.fc13 = nn.Linear(hidden_size, hidden_size)
        self.fc14 = nn.Linear(hidden_size, hidden_size)
        self.fc15 = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out[:, -1, :])
        out = torch.relu(self.fc1(out))
        out = torch.relu(self.fc2(out))
        out = torch.relu(self.fc3(out))
        out = torch.relu(self.fc4(out))
        out = torch.relu(self.fc5(out))
        out = torch.relu(self.fc6(out))
        out = torch.relu(self.fc7(out))
        out = torch.relu(self.fc8(out))
        out = torch.relu(self.fc9(out))
        out = torch.relu(self.fc10(out))
        out = torch.relu(self.fc11(out))
        out = torch.relu(self.fc12(out))
        out = torch.relu(self.fc13(out))
        out = torch.relu(self.fc14(out))
        out = self.fc15(out)
        return out

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the trained model
model_path = "C:/Users/gunne/Documents/PriceNeuralNetwork/ProfitBS0.5/005model.pth"
model = BitcoinPriceLSTM(input_size, hidden_size, num_layers, output_size, dropout=0.5).to(device)
model.load_state_dict(torch.load(model_path))
model.eval()

# Load the backtest data
backtest_data_path = 'C:/Users/gunne/OneDrive/Desktop/bitcoin/trained/1walk_cleaned.csv'
backtest_data = pd.read_csv(backtest_data_path, parse_dates=['DateTime'], index_col='DateTime')

# Feature engineering
backtest_data['Change_Open_Close'] = ((backtest_data['CLOSE'] - backtest_data['OPEN']) / backtest_data['OPEN']) * 100
backtest_data['Change_High_Low'] = ((backtest_data['HIGH'] - backtest_data['LOW']) / backtest_data['HIGH']) * 100
backtest_data['Profit_Between_Time_Series'] = backtest_data['Change_Open_Close'].diff().fillna(0)
backtest_data['Buy_Signal'] = (backtest_data['Profit_Between_Time_Series'] > 0.165).astype(int)
backtest_data['Sell_Signal'] = backtest_data['Buy_Signal'].shift(-1).fillna(0).astype(int)

# Prepare features for model prediction
features = backtest_data.drop(columns=['Buy_Signal', 'Sell_Signal']).values
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

print(f'Scaled features shape: {scaled_features.shape}')
print(f'Feature columns: {backtest_data.drop(columns=["Buy_Signal", "Sell_Signal"]).columns}')

# Predicting buy signals
with torch.no_grad():
    inputs = torch.tensor(scaled_features, dtype=torch.float32).to(device)
    outputs = model(inputs.unsqueeze(1))
    predicted_signals = torch.argmax(outputs, dim=1).cpu().numpy()

backtest_data['Predicted_Buy_Signal'] = predicted_signals

# Backtesting with leverage and profit cap
initial_capital = 100
capital = initial_capital
leverage = 100  # 1:100 leverage
capital_history = []

# Profit cap parameter
profit_cap_percentage = 0.05  # Cap the profit at this percentage
target_capital = 200000  # Target capital to stop trading

# Trade log
trade_log = []

# Initialize variables
entry_price = None
positions = 0

for i in range(len(backtest_data)):
    date_time = backtest_data.index[i]
    current_price = backtest_data['CLOSE'].iloc[i]

    if capital >= target_capital:
        print(f"Target capital of {target_capital} reached at {date_time}, stopping trading.")
        break

    if backtest_data['Predicted_Buy_Signal'].iloc[i] == 1 and positions == 0:
        # Enter position
        positions = leverage * (capital / current_price)
        entry_price = current_price
        trade_log.append(f"Entered position at {date_time}, index {i}, price: {entry_price}, positions: {positions}, capital: {capital}")
    
    if positions != 0:
        profit_percentage = (current_price - entry_price) / entry_price * 100
        
        if profit_percentage >= profit_cap_percentage or profit_percentage <= -1:
            
            # Compound the capital if profit was made
            if profit_percentage >= profit_cap_percentage:
                capital *= (1 + (profit_percentage / 100) * leverage)
                
            trade_log.append(f"Exited position at {date_time}, index {i}, price: {current_price}, profit_percentage: {profit_percentage}, capital: {capital}")
            
            # Reset positions
            positions = 0
            entry_price = None
    
    # Update capital history
    capital_history.append(capital)

# Fill the remaining capital history with the final capital value
if len(capital_history) < len(backtest_data):
    capital_history.extend([capital] * (len(backtest_data) - len(capital_history)))

# Output trade log
for log in trade_log:
    print(log)

# Plotting the results
backtest_data['Capital'] = capital_history

plt.figure(figsize=(14, 7))

plt.subplot(2, 1, 1)
plt.plot(backtest_data.index, backtest_data['CLOSE'], label='Market Price')
plt.scatter(backtest_data.index[backtest_data['Predicted_Buy_Signal'] == 1], backtest_data['CLOSE'][backtest_data['Predicted_Buy_Signal'] == 1], marker='^', color='green', alpha=1, label='Buy Signal')
plt.scatter(backtest_data.index[backtest_data['Predicted_Buy_Signal'] == 0], backtest_data['CLOSE'][backtest_data['Predicted_Buy_Signal'] == 0], marker='v', color='red', alpha=1, label='Sell Signal')
plt.title('Backtest Trading Performance')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(backtest_data.index, backtest_data['Capital'], label='Capital')
plt.axhline(y=initial_capital, color='r', linestyle='--', label='Initial Capital')
plt.axhline(y=target_capital, color='g', linestyle='--', label='Target Capital')
plt.title('Capital Growth Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

plt.tight_layout()
plt.show()

# Calculate performance metrics
actual_signals = backtest_data['Buy_Signal'].values
precision = precision_score(actual_signals, predicted_signals)
recall = recall_score(actual_signals, predicted_signals)
f1 = f1_score(actual_signals, predicted_signals)
accuracy = accuracy_score(actual_signals, predicted_signals)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 61
#      59 model_path = "C:/Users/gunne/Documents/PriceNeuralNetwork/ProfitBS0.5/005model.pth"
#      60 model = BitcoinPriceLSTM(input_size, hidden_size, num_layers, output_size, dropout=0.5).to(device)
# ---> 61 model.load_state_dict(torch.load(model_path))
#      62 model.eval()
#      64 # Load the backtest data
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2189, in Module.load_state_dict(self, state_dict, strict, assign)
#    2184         error_msgs.insert(
#    2185             0, 'Missing key(s) in state_dict: {}. '.format(
#    2186                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2188 if len(error_msgs) > 0:
# -> 2189     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for BitcoinPriceLSTM:
# 	Missing key(s) in state_dict: "lstm.weight_ih_l3", "lstm.weight_hh_l3", "lstm.bias_ih_l3", "lstm.bias_hh_l3", "lstm.weight_ih_l4", "lstm.weight_hh_l4", "lstm.bias_ih_l4", "lstm.bias_hh_l4", "lstm.weight_ih_l5", "lstm.weight_hh_l5", "lstm.bias_ih_l5", "lstm.bias_hh_l5", "lstm.weight_ih_l6", "lstm.weight_hh_l6", "lstm.bias_ih_l6", "lstm.bias_hh_l6", "lstm.weight_ih_l7", "lstm.weight_hh_l7", "lstm.bias_ih_l7", "lstm.bias_hh_l7".
# 	size mismatch for lstm.weight_ih_l0: copying a param with shape torch.Size([2048, 10]) from checkpoint, the shape in current model is torch.Size([4096, 10]).
# 	size mismatch for lstm.weight_hh_l0: copying a param with shape torch.Size([2048, 512]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for lstm.bias_ih_l0: copying a param with shape torch.Size([2048]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for lstm.bias_hh_l0: copying a param with shape torch.Size([2048]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for lstm.weight_ih_l1: copying a param with shape torch.Size([2048, 512]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for lstm.weight_hh_l1: copying a param with shape torch.Size([2048, 512]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for lstm.bias_ih_l1: copying a param with shape torch.Size([2048]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for lstm.bias_hh_l1: copying a param with shape torch.Size([2048]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for lstm.weight_ih_l2: copying a param with shape torch.Size([2048, 512]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for lstm.weight_hh_l2: copying a param with shape torch.Size([2048, 512]) from checkpoint, the shape in current model is torch.Size([4096, 1024]).
# 	size mismatch for lstm.bias_ih_l2: copying a param with shape torch.Size([2048]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for lstm.bias_hh_l2: copying a param with shape torch.Size([2048]) from checkpoint, the shape in current model is torch.Size([4096]).
# 	size mismatch for fc1.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc1.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc2.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc2.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc3.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc3.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc4.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc4.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc5.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc5.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc6.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc6.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc7.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc7.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc8.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc8.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc9.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc9.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc10.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc10.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc11.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc11.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc12.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc12.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc13.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc13.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc14.weight: copying a param with shape torch.Size([512, 512]) from checkpoint, the shape in current model is torch.Size([1024, 1024]).
# 	size mismatch for fc14.bias: copying a param with shape torch.Size([512]) from checkpoint, the shape in current model is torch.Size([1024]).
# 	size mismatch for fc15.weight: copying a param with shape torch.Size([2, 512]) from checkpoint, the shape in current model is torch.Size([2, 1024]).

# %%
#Backtesting--Connecting with MetaTrader5 data with ICMarketsSC-Demo Bitcoin account 
# Install Required Packages
# !pip install --upgrade pip
# !pip install --force-reinstall --no-binary :all: tbb
# !pip install MetaTrader5 pandas numpy torch matplotlib scikit-learn

# Imports and Model Definition
import MetaTrader5 as mt5
import pandas as pd
import datetime
import torch
import torch.nn as nn
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Define the RNN model with batch normalization and 15 activation layers
class BitcoinPriceLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
        super(BitcoinPriceLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, hidden_size)
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.fc6 = nn.Linear(hidden_size, hidden_size)
        self.fc7 = nn.Linear(hidden_size, hidden_size)
        self.fc8 = nn.Linear(hidden_size, hidden_size)
        self.fc9 = nn.Linear(hidden_size, hidden_size)
        self.fc10 = nn.Linear(hidden_size, hidden_size)
        self.fc11 = nn.Linear(hidden_size, hidden_size)
        self.fc12 = nn.Linear(hidden_size, hidden_size)
        self.fc13 = nn.Linear(hidden_size, hidden_size)
        self.fc14 = nn.Linear(hidden_size, hidden_size)
        self.fc15 = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out[:, -1, :])
        out = torch.relu(self.fc1(out))
        out = torch.relu(self.fc2(out))
        out = torch.relu(self.fc3(out))
        out = torch.relu(self.fc4(out))
        out = torch.relu(self.fc5(out))
        out = torch.relu(self.fc6(out))
        out = torch.relu(self.fc7(out))
        out = torch.relu(self.fc8(out))
        out = torch.relu(self.fc9(out))
        out = torch.relu(self.fc10(out))
        out = torch.relu(self.fc11(out))
        out = torch.relu(self.fc12(out))
        out = torch.relu(self.fc13(out))
        out = torch.relu(self.fc14(out))
        out = self.fc15(out)
        return out

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Load the trained model
model_path = "C:/Users/gunne/Documents/PriceNeuralNetwork/ProfitBS0.5/005_1model.pth"
model = BitcoinPriceLSTM(input_size=10, hidden_size=1024, num_layers=10, output_size=2, dropout=0.5).to(device)
model.load_state_dict(torch.load(model_path))
model.eval()

# Connect to MetaTrader 5
if not mt5.initialize():
    print("initialize() failed")
    mt5.shutdown()
else:
    print("MetaTrader 5 initialized successfully")

# Login to the demo account
account = 51806647  # Ensure the account number is an integer
password = "lKDtOjEK6$rp@f"
server = "ICMarketsSC-Demo"

# Debug print for login details
print(f"Attempting to login with Account: {account}, Password: {password}, Server: {server}")

authorized = mt5.login(login=account, password=password, server=server)
if not authorized:
    print(f"Failed to connect to account #{account}, error code: {mt5.last_error()}")
else:
    print(f"Connected to account #{account}")
# Out:
# Requirement already satisfied: pip in c:\users\gunne\anaconda3\lib\site-packages (23.2.1)
# Collecting pip
#   Obtaining dependency information for pip from https://files.pythonhosted.org/packages/8a/6a/19e9fe04fca059ccf770861c7d5721ab4c2aebc539889e97c7977528a53b/pip-24.0-py3-none-any.whl.metadata
#   Using cached pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.0-py3-none-any.whl (2.1 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\gunne\anaconda3\python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement tbb (from versions: none)
# ERROR: No matching distribution found for tbb
# Requirement already satisfied: MetaTrader5 in c:\users\gunne\anaconda3\lib\site-packages (5.0.4288)
# Requirement already satisfied: pandas in c:\users\gunne\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\gunne\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: torch in c:\users\gunne\anaconda3\lib\site-packages (2.3.0+cu121)
# Requirement already satisfied: matplotlib in c:\users\gunne\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: scikit-learn in c:\users\gunne\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gunne\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gunne\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gunne\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in c:\users\gunne\anaconda3\lib\site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\gunne\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\gunne\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\gunne\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\gunne\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\gunne\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\gunne\anaconda3\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\gunne\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\gunne\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gunne\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\gunne\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gunne\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gunne\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gunne\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Installing collected packages: tbb
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 70
#      68 model_path = "C:/Users/gunne/Documents/PriceNeuralNetwork/ProfitBS0.5/005_1model.pth"
#      69 model = BitcoinPriceLSTM(input_size=10, hidden_size=1024, num_layers=10, output_size=2, dropout=0.5).to(device)
# ---> 70 model.load_state_dict(torch.load(model_path))
#      71 model.eval()
#      73 # Connect to MetaTrader 5
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:2189, in Module.load_state_dict(self, state_dict, strict, assign)
#    2184         error_msgs.insert(
#    2185             0, 'Missing key(s) in state_dict: {}. '.format(
#    2186                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2188 if len(error_msgs) > 0:
# -> 2189     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2190                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2191 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for BitcoinPriceLSTM:
# 	Missing key(s) in state_dict: "lstm.weight_ih_l8", "lstm.weight_hh_l8", "lstm.bias_ih_l8", "lstm.bias_hh_l8", "lstm.weight_ih_l9", "lstm.weight_hh_l9", "lstm.bias_ih_l9", "lstm.bias_hh_l9".

# %%
#Backtesting--Part 2
# Fetch historical data from MetaTrader 5
symbol = "BTCUSD"
timeframe = mt5.TIMEFRAME_M1
utc_from = datetime.datetime(2022, 6, 1)
utc_to = datetime.datetime(2022, 7, 1)
rates = mt5.copy_rates_range(symbol, timeframe, utc_from, utc_to)
if rates is None:
    print("Failed to fetch rates, error code:", mt5.last_error())
else:
    print(f"Fetched {len(rates)} rates")

# Create DataFrame from the rates
rates_frame = pd.DataFrame(rates)
rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')
rates_frame.set_index('time', inplace=True)

# Feature engineering
rates_frame['Change_Open_Close'] = ((rates_frame['close'] - rates_frame['open']) / rates_frame['open']) * 100
rates_frame['Change_High_Low'] = ((rates_frame['high'] - rates_frame['low']) / rates_frame['high']) * 100
rates_frame['Profit_Between_Time_Series'] = rates_frame['Change_Open_Close'].diff().fillna(0)
rates_frame['Buy_Signal'] = (rates_frame['Profit_Between_Time_Series'] > 0.165).astype(int)
rates_frame['Sell_Signal'] = rates_frame['Buy_Signal'].shift(-1).fillna(0).astype(int)

# Prepare features for model prediction
features = rates_frame.drop(columns=['Buy_Signal', 'Sell_Signal']).values
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Predicting buy signals
with torch.no_grad():
    inputs = torch.tensor(scaled_features, dtype=torch.float32).to(device)
    outputs = model(inputs.unsqueeze(1))
    predicted_signals = torch.argmax(outputs, dim=1).cpu().numpy()

rates_frame['Predicted_Buy_Signal'] = predicted_signals

# Backtesting with leverage and profit cap
initial_capital = 100
risk_per_trade = 10  # Risking $10 per trade
capital = initial_capital
leverage = 100  # 1:100 leverage
capital_history = []

# Profit cap parameter
profit_cap_percentage = 0.165  # Cap the profit at this percentage

# Trade log
trade_log = []

# Initialize variables
entry_price = None
positions = 0

for i in range(len(rates_frame)):
    date_time = rates_frame.index[i]
    current_price = rates_frame['close'].iloc[i]

    if rates_frame['Predicted_Buy_Signal'].iloc[i] == 1 and positions == 0:
        # Enter position
        positions = leverage * (risk_per_trade / current_price)
        entry_price = current_price
        trade_log.append(f"Entered position at index {i}, time {date_time}, price: {entry_price}, positions: {positions}, capital: {capital}")

    if positions != 0:
        profit_percentage = (current_price - entry_price) / entry_price * 100

        if profit_percentage >= profit_cap_percentage or profit_percentage <= -1:
            # Exit position due to reaching profit cap or stop loss
            profit = positions * (current_price - entry_price) * leverage
            capital += profit

            trade_log.append(f"Exited position at index {i}, time {date_time}, price: {current_price}, profit_percentage: {profit_percentage}, profit: {profit}, capital: {capital}")

            # Compound the capital if profit was made
            if profit_percentage >= profit_cap_percentage:
                capital += profit  # Add profit directly to capital

            # Reset positions
            positions = 0
            entry_price = None

    # Update capital history
    capital_history.append(capital)

# Output trade log
for log in trade_log:
    print(log)

# Plotting the results
rates_frame['Capital'] = capital_history

plt.figure(figsize=(14, 7))

plt.subplot(2, 1, 1)
plt.plot(rates_frame.index, rates_frame['close'], label='Market Price')
plt.scatter(rates_frame.index[rates_frame['Predicted_Buy_Signal'] == 1], rates_frame['close'][rates_frame['Predicted_Buy_Signal'] == 1], marker='^', color='green', alpha=1, label='Buy Signal')
plt.scatter(rates_frame.index[rates_frame['Predicted_Buy_Signal'] == 0], rates_frame['close'][rates_frame['Predicted_Buy_Signal'] == 0], marker='v', color='red', alpha=1, label='Sell Signal')
plt.title('Backtest Trading Performance')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(rates_frame.index, rates_frame['Capital'], label='Capital')
plt.axhline(y=initial_capital, color='r', linestyle='--', label='Initial Capital')
plt.axhline(y=200000, color='g', linestyle='--', label='Target Capital')
plt.title('Capital Growth Over Time')
plt.xlabel('Date')
plt.ylabel('Capital')
plt.legend()

plt.tight_layout()
plt.show()

# Calculate performance metrics
actual_signals = rates_frame['Buy_Signal'].values
precision = precision_score(actual_signals, predicted_signals)
recall = recall_score(actual_signals, predicted_signals)
f1 = f1_score(actual_signals, predicted_signals)
accuracy = accuracy_score(actual_signals, predicted_signals)

print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Fetched 42595 rates
# Entered position at index 3, time 2022-05-31 23:03:00, price: 31650.89, positions: 0.03159468817464532, capital: 100
# Exited position at index 13, time 2022-05-31 23:13:00, price: 31710.91, profit_percentage: 0.18963131842422262, profit: 189.6313184242226, capital: 289.6313184242226
# Entered position at index 16, time 2022-05-31 23:16:00, price: 31691.49, positions: 0.03155421218756202, capital: 479.26263684844525
# Exited position at index 54, time 2022-05-31 23:54:00, price: 31768.31, profit_percentage: 0.24239945802485055, profit: 242.39945802485053, capital: 721.6620948732958
# Entered position at index 59, time 2022-06-01 00:05:00, price: 31757.82, positions: 0.03148830744679578, capital: 964.0615528981464
# Exited position at index 157, time 2022-06-01 01:43:00, price: 31814.06, profit_percentage: 0.17709024108078453, profit: 177.0902410807845, capital: 1141.151793978931
# Entered position at index 161, time 2022-06-01 01:47:00, price: 31803.16, positions: 0.03144341631460522, capital: 1318.2420350597154
# Exited position at index 175, time 2022-06-01 02:01:00, price: 31855.9, profit_percentage: 0.16583257764323295, profit: 165.83257764323295, capital: 1484.0746127029483
# Entered position at index 178, time 2022-06-01 02:04:00, price: 31852.65, positions: 0.03139456214789037, capital: 1649.9071903461813
# Exited position at index 274, time 2022-06-01 03:40:00, price: 31950.81, profit_percentage: 0.30816902204369134, profit: 308.1690220436914, capital: 1958.0762123898728
# Entered position at index 276, time 2022-06-01 03:42:00, price: 31909.72, positions: 0.03133841349908429, capital: 2266.2452344335643
# Exited position at index 470, time 2022-06-01 06:56:00, price: 31586.55, profit_percentage: -1.012763509049913, profit: -1012.763509049913, capital: 1253.4817253836513
# Entered position at index 471, time 2022-06-01 06:57:00, price: 31586.04, positions: 0.0316595559304047, capital: 1253.4817253836513
# Exited position at index 599, time 2022-06-01 09:05:00, price: 31643.82, profit_percentage: 0.18292891416587465, profit: 182.92891416587466, capital: 1436.410639549526
# Entered position at index 605, time 2022-06-01 09:11:00, price: 31603.88, positions: 0.0316416845020295, capital: 1619.3395537154006
# Exited position at index 814, time 2022-06-01 12:40:00, price: 31656.25, profit_percentage: 0.16570750173712526, profit: 165.70750173712526, capital: 1785.047055452526
# Entered position at index 815, time 2022-06-01 12:41:00, price: 31672.16, positions: 0.03157347020222176, capital: 1950.7545571896512
# Exited position at index 996, time 2022-06-01 15:42:00, price: 31773.34, profit_percentage: 0.31946037150608075, profit: 319.46037150608066, capital: 2270.214928695732
# Entered position at index 999, time 2022-06-01 15:45:00, price: 31786.91, positions: 0.03145949071488861, capital: 2589.6753002018127
# Exited position at index 1039, time 2022-06-01 16:25:00, price: 31840.57, profit_percentage: 0.16881162717609183, profit: 168.81162717609183, capital: 2758.4869273779045
# Entered position at index 1041, time 2022-06-01 16:27:00, price: 31822.07, positions: 0.031424731326403346, capital: 2927.2985545539964
# Exited position at index 1089, time 2022-06-01 17:15:00, price: 31467.71, profit_percentage: -1.1135667792824306, profit: -1113.5667792824306, capital: 1813.7317752715658
# Entered position at index 1092, time 2022-06-01 17:18:00, price: 31446.4, positions: 0.03180014246463824, capital: 1813.7317752715658
# Exited position at index 1109, time 2022-06-01 17:35:00, price: 31119.31, profit_percentage: -1.0401508598758527, profit: -1040.1508598758528, capital: 773.580915395713
# Entered position at index 1111, time 2022-06-01 17:37:00, price: 31078.67, positions: 0.03217640909343933, capital: 773.580915395713
# Exited position at index 1113, time 2022-06-01 17:39:00, price: 31156.67, profit_percentage: 0.2509759909288268, profit: 250.97599092882677, capital: 1024.5569063245398
# Entered position at index 1115, time 2022-06-01 17:41:00, price: 31114.16, positions: 0.03213970745152689, capital: 1275.5328972533666
# Exited position at index 1128, time 2022-06-01 17:54:00, price: 31197.24, profit_percentage: 0.26701668950729107, profit: 267.016689507291, capital: 1542.5495867606576
# Entered position at index 1131, time 2022-06-01 17:57:00, price: 31235.06, positions: 0.03201530587743388, capital: 1809.5662762679485
# Exited position at index 1157, time 2022-06-01 18:23:00, price: 30847.4, profit_percentage: -1.2411053476446015, profit: -1241.1053476446014, capital: 568.4609286233472
# Entered position at index 1158, time 2022-06-01 18:24:00, price: 30929.9, positions: 0.032331174688569955, capital: 568.4609286233472
# Exited position at index 1197, time 2022-06-01 19:03:00, price: 30618.62, profit_percentage: -1.0064048057058137, profit: -1006.4048057058136, capital: -437.94387708246643
# Entered position at index 1198, time 2022-06-01 19:04:00, price: 30628.2, positions: 0.03264964966925905, capital: -437.94387708246643
# Exited position at index 1242, time 2022-06-01 19:48:00, price: 30262.08, profit_percentage: -1.195368973690909, profit: -1195.368973690909, capital: -1633.3128507733754
# Entered position at index 1243, time 2022-06-01 19:49:00, price: 30292.08, positions: 0.033011929190732356, capital: -1633.3128507733754
# Exited position at index 1246, time 2022-06-01 19:52:00, price: 30349.58, profit_percentage: 0.1898185928467111, profit: 189.81859284671106, capital: -1443.4942579266644
# Entered position at index 1254, time 2022-06-01 20:00:00, price: 30395.99, positions: 0.03289907649002385, capital: -1253.6756650799534
# Exited position at index 1275, time 2022-06-01 20:21:00, price: 29992.16, profit_percentage: -1.328563405896639, profit: -1328.5634058966386, capital: -2582.2390709765923
# Entered position at index 1277, time 2022-06-01 20:23:00, price: 29876.74, positions: 0.03347085391511925, capital: -2582.2390709765923
# Exited position at index 1278, time 2022-06-01 20:24:00, price: 29949.74, profit_percentage: 0.24433723358037052, profit: 244.33723358037054, capital: -2337.9018373962217
# Entered position at index 1281, time 2022-06-01 20:27:00, price: 30003.24, positions: 0.033329733722091345, capital: -2093.564603815851
# Exited position at index 1290, time 2022-06-01 20:36:00, price: 30083.94, profit_percentage: 0.26897095113726743, profit: 268.97095113726743, capital: -1824.5936526785836
# Entered position at index 1293, time 2022-06-01 20:39:00, price: 30180.67, positions: 0.033133790601732833, capital: -1555.622701541316
# Exited position at index 1336, time 2022-06-01 21:22:00, price: 30263.47, profit_percentage: 0.2743477861823575, profit: 274.34778618235754, capital: -1281.2749153589584
# Entered position at index 1348, time 2022-06-01 21:34:00, price: 30273.1, positions: 0.03303262632502123, capital: -1006.9271291766008
# Exited position at index 1350, time 2022-06-01 21:36:00, price: 30340.13, profit_percentage: 0.22141769425662547, profit: 221.41769425662545, capital: -785.5094349199753
# Entered position at index 1353, time 2022-06-01 21:39:00, price: 30318.31, positions: 0.03298336879595202, capital: -564.0917406633498
# Exited position at index 1358, time 2022-06-01 21:44:00, price: 30395.81, profit_percentage: 0.2556211081686281, profit: 255.62110816862815, capital: -308.47063249472166
# Entered position at index 1362, time 2022-06-01 21:48:00, price: 30350.31, positions: 0.03294859261734064, capital: -52.8495243260935
# Exited position at index 1377, time 2022-06-01 22:03:00, price: 29974.84, profit_percentage: -1.237120807003293, profit: -1237.120807003293, capital: -1289.9703313293867
# Entered position at index 1378, time 2022-06-01 22:04:00, price: 30031.88, positions: 0.03329794871316748, capital: -1289.9703313293867
# Exited position at index 1380, time 2022-06-01 22:06:00, price: 30128.03, profit_percentage: 0.32015977687709796, profit: 320.159776877098, capital: -969.8105544522887
# Entered position at index 1385, time 2022-06-01 22:11:00, price: 30105.06, positions: 0.0332170073735113, capital: -649.6507775751907
# Exited position at index 1387, time 2022-06-01 22:13:00, price: 30160.66, profit_percentage: 0.18468656099671796, profit: 184.686560996718, capital: -464.9642165784727
# Entered position at index 1390, time 2022-06-01 22:16:00, price: 30239.8, positions: 0.033069001779112296, capital: -280.27765558175474
# Exited position at index 1461, time 2022-06-01 23:27:00, price: 29811.49, profit_percentage: -1.4163784152011512, profit: -1416.378415201151, capital: -1696.6560707829058
# Entered position at index 1463, time 2022-06-01 23:29:00, price: 29562.28, positions: 0.0338268902127982, capital: -1696.6560707829058
# Exited position at index 1484, time 2022-06-01 23:50:00, price: 29635.6, profit_percentage: 0.24801875904023543, profit: 248.0187590402354, capital: -1448.6373117426704
# Entered position at index 1487, time 2022-06-01 23:53:00, price: 29672.02, positions: 0.033701783700604136, capital: -1200.618552702435
# Exited position at index 1494, time 2022-06-02 00:06:00, price: 29722.62, profit_percentage: 0.17053102552505203, profit: 170.53102552505203, capital: -1030.087527177383
# Entered position at index 1496, time 2022-06-02 00:08:00, price: 29709.83, positions: 0.033658893369635574, capital: -859.556501652331
# Exited position at index 1613, time 2022-06-02 02:05:00, price: 29773.86, profit_percentage: 0.2155178942457726, profit: 215.51789424577268, capital: -644.0386074065583
# Entered position at index 1614, time 2022-06-02 02:06:00, price: 29885.24, positions: 0.03346133409000563, capital: -428.5207131607856
# Exited position at index 1615, time 2022-06-02 02:07:00, price: 29952.0, profit_percentage: 0.22338786638487224, profit: 223.38786638487224, capital: -205.13284677591335
# Entered position at index 1620, time 2022-06-02 02:12:00, price: 29876.23, positions: 0.033471425276884, capital: 18.25501960895889
# Exited position at index 1623, time 2022-06-02 02:15:00, price: 29927.73, profit_percentage: 0.1723778401759526, profit: 172.3778401759526, capital: 190.6328597849115
# Entered position at index 1625, time 2022-06-02 02:17:00, price: 29802.68, positions: 0.033554029369170825, capital: 363.0106999608641
# Exited position at index 1632, time 2022-06-02 02:24:00, price: 29862.66, profit_percentage: 0.20125706815628513, profit: 201.25706815628513, capital: 564.2677681171492
# Entered position at index 1637, time 2022-06-02 02:29:00, price: 29887.07, positions: 0.03345928523605693, capital: 765.5248362734344
# Exited position at index 1702, time 2022-06-02 03:34:00, price: 29569.24, profit_percentage: -1.0634364626575912, profit: -1063.4364626575912, capital: -297.91162638415676
# Entered position at index 1703, time 2022-06-02 03:35:00, price: 29572.21, positions: 0.03381553154126797, capital: -297.91162638415676
# Exited position at index 1705, time 2022-06-02 03:37:00, price: 29632.21, profit_percentage: 0.20289318924760782, profit: 202.89318924760784, capital: -95.01843713654893
# Entered position at index 1708, time 2022-06-02 03:40:00, price: 29681.21, positions: 0.03369134883651981, capital: 107.87475211105891
# Exited position at index 1720, time 2022-06-02 03:52:00, price: 29763.02, profit_percentage: 0.2756289248315729, profit: 275.62892483157293, capital: 383.50367694263184
# Entered position at index 1723, time 2022-06-02 03:55:00, price: 29651.8, positions: 0.03372476544425634, capital: 659.1326017742048
# Exited position at index 1734, time 2022-06-02 04:06:00, price: 29717.35, profit_percentage: 0.22106583748709782, profit: 221.06583748709784, capital: 880.1984392613026
# Entered position at index 1738, time 2022-06-02 04:10:00, price: 29771.42, positions: 0.03358926111015195, capital: 1101.2642767484003
# Exited position at index 1768, time 2022-06-02 04:40:00, price: 29823.66, profit_percentage: 0.17547030003943917, profit: 175.47030003943917, capital: 1276.7345767878396
# Entered position at index 1772, time 2022-06-02 04:44:00, price: 29799.63, positions: 0.03355746363293772, capital: 1452.204876827279
# Exited position at index 2022, time 2022-06-02 08:54:00, price: 29849.91, profit_percentage: 0.16872692714640697, profit: 168.72692714640692, capital: 1620.9318039736859
# Entered position at index 2032, time 2022-06-02 09:04:00, price: 29855.91, positions: 0.03349420600477426, capital: 1789.6587311200929
# Exited position at index 2088, time 2022-06-02 10:00:00, price: 29908.03, profit_percentage: 0.17457180169688005, profit: 174.57180169688004, capital: 1964.230532816973
# Entered position at index 2091, time 2022-06-02 10:03:00, price: 29929.47, positions: 0.033411884674202384, capital: 2138.802334513853
# Exited position at index 2114, time 2022-06-02 10:26:00, price: 30005.29, profit_percentage: 0.2533289095998015, profit: 253.32890959980153, capital: 2392.1312441136547
# Entered position at index 2116, time 2022-06-02 10:28:00, price: 30027.3, positions: 0.03330302757823714, capital: 2645.4601537134563
# Exited position at index 2313, time 2022-06-02 13:45:00, price: 30080.55, profit_percentage: 0.17733862185411275, profit: 177.33862185411274, capital: 2822.798775567569
# Entered position at index 2315, time 2022-06-02 13:47:00, price: 29912.07, positions: 0.033431320533817956, capital: 3000.1373974216817
# Exited position at index 2324, time 2022-06-02 13:56:00, price: 29963.08, profit_percentage: 0.1705331660430122, profit: 170.53316604301222, capital: 3170.670563464694
# Entered position at index 2333, time 2022-06-02 14:05:00, price: 29952.29, positions: 0.033386428884068634, capital: 3341.203729507706
# Exited position at index 2343, time 2022-06-02 14:15:00, price: 30015.24, profit_percentage: 0.21016756982521445, profit: 210.16756982521449, capital: 3551.3712993329204
# Entered position at index 2347, time 2022-06-02 14:19:00, price: 29972.6, positions: 0.033363805609123, capital: 3761.5388691581347
# Exited position at index 2354, time 2022-06-02 14:26:00, price: 30023.66, profit_percentage: 0.17035559144018642, profit: 170.3555914401864, capital: 3931.894460598321
# Entered position at index 2356, time 2022-06-02 14:28:00, price: 30064.91, positions: 0.03326136682265139, capital: 4102.250052038507
# Exited position at index 2380, time 2022-06-02 14:52:00, price: 30116.07, profit_percentage: 0.17016515266468402, profit: 170.16515266468403, capital: 4272.415204703191
# Entered position at index 2384, time 2022-06-02 14:56:00, price: 30143.66, positions: 0.03317447184582098, capital: 4442.580357367875
# Exited position at index 2460, time 2022-06-02 16:12:00, price: 29826.46, profit_percentage: -1.0522942469494438, profit: -1052.2942469494437, capital: 3390.2861104184312
# Entered position at index 2462, time 2022-06-02 16:14:00, price: 29715.81, positions: 0.0336521198648127, capital: 3390.2861104184312
# Exited position at index 2476, time 2022-06-02 16:28:00, price: 29848.48, profit_percentage: 0.4464626742464643, profit: 446.46267424646425, capital: 3836.7487846648955
# Entered position at index 2479, time 2022-06-02 16:31:00, price: 29690.1, positions: 0.03368126075695266, capital: 4283.21145891136
# Exited position at index 2480, time 2022-06-02 16:32:00, price: 29743.1, profit_percentage: 0.17851068201184908, profit: 178.51068201184907, capital: 4461.722140923209
# Entered position at index 2485, time 2022-06-02 16:37:00, price: 29751.99, positions: 0.033611197099757024, capital: 4640.232822935058
# Exited position at index 2487, time 2022-06-02 16:39:00, price: 29851.49, profit_percentage: 0.33443141114258235, profit: 334.4314111425824, capital: 4974.66423407764
# Entered position at index 2489, time 2022-06-02 16:41:00, price: 29924.12, positions: 0.03341785823609851, capital: 5309.095645220223
# Exited position at index 2490, time 2022-06-02 16:42:00, price: 30121.38, profit_percentage: 0.659200671565286, profit: 659.200671565286, capital: 5968.296316785509
# Entered position at index 2494, time 2022-06-02 16:46:00, price: 30037.04, positions: 0.03329222852851013, capital: 6627.496988350795
# Exited position at index 2521, time 2022-06-02 17:13:00, price: 30104.39, profit_percentage: 0.2242231591395109, profit: 224.22315913951087, capital: 6851.720147490306
# Entered position at index 2524, time 2022-06-02 17:16:00, price: 30063.86, positions: 0.033262528497671286, capital: 7075.943306629817
# Exited position at index 2576, time 2022-06-02 18:08:00, price: 30126.78, profit_percentage: 0.20928782930734197, profit: 209.28782930734192, capital: 7285.231135937159
# Entered position at index 2578, time 2022-06-02 18:10:00, price: 30182.41, positions: 0.03313188045619948, capital: 7494.518965244501
# Exited position at index 2591, time 2022-06-02 18:23:00, price: 30309.01, profit_percentage: 0.4194496065754807, profit: 419.44960657548063, capital: 7913.968571819982
# Entered position at index 2594, time 2022-06-02 18:26:00, price: 30285.51, positions: 0.03301909064763975, capital: 8333.418178395463
# Exited position at index 2609, time 2022-06-02 18:41:00, price: 30345.43, profit_percentage: 0.1978503911606636, profit: 197.8503911606636, capital: 8531.268569556127
# Entered position at index 2611, time 2022-06-02 18:43:00, price: 30300.43, positions: 0.033002831973011605, capital: 8729.11896071679
# Exited position at index 2645, time 2022-06-02 19:17:00, price: 30362.29, profit_percentage: 0.20415551858505168, profit: 204.1555185850517, capital: 8933.274479301843
# Entered position at index 2648, time 2022-06-02 19:20:00, price: 30277.13, positions: 0.03302822955808559, capital: 9137.429997886895
# Exited position at index 2877, time 2022-06-02 23:09:00, price: 30352.43, profit_percentage: 0.2487025685723821, profit: 248.7025685723821, capital: 9386.132566459277
# Entered position at index 2879, time 2022-06-02 23:11:00, price: 30326.93, positions: 0.032973993740876506, capital: 9634.835135031659
# Exited position at index 2989, time 2022-06-03 01:07:00, price: 30636.94, profit_percentage: 1.0222267799609073, profit: 1022.2267799609073, capital: 10657.061914992566
# Entered position at index 2991, time 2022-06-03 01:09:00, price: 30512.94, positions: 0.03277298090580587, capital: 11679.288694953473
# Exited position at index 2992, time 2022-06-03 01:10:00, price: 30568.83, profit_percentage: 0.183168190282559, profit: 183.168190282559, capital: 11862.456885236032
# Entered position at index 2996, time 2022-06-03 01:14:00, price: 30442.05, positions: 0.032849298913837935, capital: 12045.62507551859
# Exited position at index 3004, time 2022-06-03 01:22:00, price: 30503.99, profit_percentage: 0.2034685574723198, profit: 203.4685574723198, capital: 12249.09363299091
# Entered position at index 3007, time 2022-06-03 01:25:00, price: 30440.78, positions: 0.032850669398090324, capital: 12452.562190463228
# Exited position at index 3022, time 2022-06-03 01:40:00, price: 30516.82, profit_percentage: 0.2497964901030817, profit: 249.79649010308168, capital: 12702.358680566309
# Entered position at index 3025, time 2022-06-03 01:43:00, price: 30549.21, positions: 0.03273407070100995, capital: 12952.15517066939
# Exited position at index 3071, time 2022-06-03 02:29:00, price: 30614.14, profit_percentage: 0.21254232106165855, profit: 212.54232106165855, capital: 13164.697491731049
# Entered position at index 3075, time 2022-06-03 02:33:00, price: 30571.18, positions: 0.032710546338087045, capital: 13377.239812792708
# Exited position at index 3203, time 2022-06-03 04:41:00, price: 30647.99, profit_percentage: 0.2512497064228509, profit: 251.2497064228509, capital: 13628.489519215558
# Entered position at index 3209, time 2022-06-03 04:47:00, price: 30532.56, positions: 0.03275192122769922, capital: 13879.739225638408
# Exited position at index 3216, time 2022-06-03 04:54:00, price: 30597.59, profit_percentage: 0.2129857437437242, profit: 212.98574374372419, capital: 14092.724969382132
# Entered position at index 3218, time 2022-06-03 04:56:00, price: 30591.67, positions: 0.03268863713553396, capital: 14305.710713125856
# Exited position at index 3528, time 2022-06-03 10:06:00, price: 30271.3, profit_percentage: -1.0472458679110979, profit: -1047.245867911098, capital: 13258.464845214758
# Entered position at index 3529, time 2022-06-03 10:07:00, price: 30288.25, positions: 0.03301610360453311, capital: 13258.464845214758
# Exited position at index 3535, time 2022-06-03 10:13:00, price: 30358.02, profit_percentage: 0.23035335484882896, profit: 230.35335484882893, capital: 13488.818200063586
# Entered position at index 3540, time 2022-06-03 10:18:00, price: 30390.27, positions: 0.0329052686929073, capital: 13719.171554912415
# Exited position at index 3566, time 2022-06-03 10:44:00, price: 30441.56, profit_percentage: 0.16877112312592443, profit: 168.77112312592442, capital: 13887.942678038338
# Entered position at index 3577, time 2022-06-03 10:55:00, price: 30433.99, positions: 0.0328579985733057, capital: 14056.713801164262
# Exited position at index 3588, time 2022-06-03 11:06:00, price: 30488.5, profit_percentage: 0.17910895022308412, profit: 179.1089502230841, capital: 14235.822751387346
# Entered position at index 3590, time 2022-06-03 11:08:00, price: 30482.41, positions: 0.032805805052815704, capital: 14414.93170161043
# Exited position at index 3666, time 2022-06-03 12:24:00, price: 30157.71, profit_percentage: -1.0652044900649285, profit: -1065.2044900649282, capital: 13349.727211545502
# Entered position at index 3667, time 2022-06-03 12:25:00, price: 30194.72, positions: 0.033118373013559986, capital: 13349.727211545502
# Exited position at index 3735, time 2022-06-03 13:33:00, price: 29881.68, profit_percentage: -1.0367375488164847, profit: -1036.7375488164846, capital: 12312.989662729016
# Entered position at index 3736, time 2022-06-03 13:34:00, price: 29903.49, positions: 0.03344091274964895, capital: 12312.989662729016
# Exited position at index 3861, time 2022-06-03 15:39:00, price: 29596.48, profit_percentage: -1.0266694623269794, profit: -1026.6694623269793, capital: 11286.320200402037
# Entered position at index 3862, time 2022-06-03 15:40:00, price: 29562.48, positions: 0.033826661362646164, capital: 11286.320200402037
# Exited position at index 3868, time 2022-06-03 15:46:00, price: 29631.21, profit_percentage: 0.23249064354546561, profit: 232.49064354546562, capital: 11518.810843947502
# Entered position at index 3873, time 2022-06-03 15:51:00, price: 29596.26, positions: 0.03378805294993354, capital: 11751.301487492967
# Exited position at index 3900, time 2022-06-03 16:18:00, price: 29650.14, profit_percentage: 0.18205002929424535, profit: 182.05002929424538, capital: 11933.351516787212
# Entered position at index 3902, time 2022-06-03 16:20:00, price: 29627.41, positions: 0.03375252848629023, capital: 12115.401546081457
# Exited position at index 3913, time 2022-06-03 16:31:00, price: 29680.01, profit_percentage: 0.1775382998378817, profit: 177.53829983788168, capital: 12292.939845919338
# Entered position at index 3923, time 2022-06-03 16:41:00, price: 29648.94, positions: 0.03372801860707331, capital: 12470.478145757219
# Exited position at index 3942, time 2022-06-03 17:00:00, price: 29698.99, profit_percentage: 0.16880873312841171, profit: 168.80873312841172, capital: 12639.28687888563
# Entered position at index 3948, time 2022-06-03 17:06:00, price: 29618.71, positions: 0.03376244272623622, capital: 12808.095612014042
# Exited position at index 3987, time 2022-06-03 17:45:00, price: 29284.0, profit_percentage: -1.1300627204898497, profit: -1130.0627204898494, capital: 11678.032891524192
# Entered position at index 3988, time 2022-06-03 17:46:00, price: 29335.88, positions: 0.034087949637099685, capital: 11678.032891524192
# Exited position at index 3991, time 2022-06-03 17:49:00, price: 29396.71, profit_percentage: 0.20735699764247098, profit: 207.35699764247096, capital: 11885.389889166663
# Entered position at index 3995, time 2022-06-03 17:53:00, price: 29448.02, positions: 0.033958140479393856, capital: 12092.746886809135
# Exited position at index 4034, time 2022-06-03 18:32:00, price: 29519.6, profit_percentage: 0.24307236955149483, profit: 243.07236955149477, capital: 12335.81925636063
# Entered position at index 4038, time 2022-06-03 18:36:00, price: 29509.61, positions: 0.03388726587711596, capital: 12578.891625912125
# Exited position at index 4126, time 2022-06-03 20:04:00, price: 29605.77, profit_percentage: 0.3258599486743466, profit: 325.85994867434664, capital: 12904.751574586471
# Entered position at index 4128, time 2022-06-03 20:06:00, price: 29583.1, positions: 0.03380308351727845, capital: 13230.611523260817
# Exited position at index 4342, time 2022-06-03 23:40:00, price: 29635.51, profit_percentage: 0.17716196071405588, profit: 177.16196071405585, capital: 13407.773483974874
# Entered position at index 4344, time 2022-06-03 23:42:00, price: 29612.28, positions: 0.03376977389110194, capital: 13584.93544468893
# Exited position at index 4352, time 2022-06-03 23:50:00, price: 29682.91, profit_percentage: 0.2385159129928564, profit: 238.5159129928564, capital: 13823.451357681786
# Entered position at index 4354, time 2022-06-03 23:52:00, price: 29660.22, positions: 0.03371519159331927, capital: 14061.967270674642
# Exited position at index 4357, time 2022-06-04 00:45:00, price: 29715.62, profit_percentage: 0.18678216142698137, profit: 186.7821614269814, capital: 14248.749432101624
# Entered position at index 4359, time 2022-06-04 00:47:00, price: 29704.62, positions: 0.03366479692384552, capital: 14435.531593528605
# Exited position at index 4362, time 2022-06-04 00:50:00, price: 29764.21, profit_percentage: 0.20060852486919592, profit: 200.60852486919592, capital: 14636.140118397801
# Entered position at index 4366, time 2022-06-04 00:54:00, price: 29798.08, positions: 0.03355920918394742, capital: 14836.748643266998
# Exited position at index 4382, time 2022-06-04 01:10:00, price: 29850.28, profit_percentage: 0.17517907194019577, profit: 175.17907194019574, capital: 15011.927715207194
# Entered position at index 4385, time 2022-06-04 01:13:00, price: 29827.1, positions: 0.03352655806296958, capital: 15187.10678714739
# Exited position at index 4557, time 2022-06-04 04:05:00, price: 29517.24, profit_percentage: -1.038853928139165, profit: -1038.8539281391652, capital: 14148.252859008224
# Entered position at index 4558, time 2022-06-04 04:06:00, price: 29538.74, positions: 0.03385384752362491, capital: 14148.252859008224
# Exited position at index 4568, time 2022-06-04 04:16:00, price: 29590.24, profit_percentage: 0.17434731474666826, profit: 174.34731474666827, capital: 14322.600173754892
# Entered position at index 4570, time 2022-06-04 04:18:00, price: 29600.53, positions: 0.03378317888227002, capital: 14496.94748850156
# Exited position at index 4745, time 2022-06-04 07:13:00, price: 29661.31, profit_percentage: 0.20533416124644552, profit: 205.33416124644552, capital: 14702.281649748005
# Entered position at index 4749, time 2022-06-04 07:17:00, price: 29641.92, positions: 0.033736006304584856, capital: 14907.61581099445
# Exited position at index 4785, time 2022-06-04 07:53:00, price: 29703.03, profit_percentage: 0.20616073452732003, profit: 206.16073452732002, capital: 15113.77654552177
# Entered position at index 4787, time 2022-06-04 07:55:00, price: 29696.53, positions: 0.03367396796864819, capital: 15319.937280049091
# Exited position at index 5005, time 2022-06-04 11:33:00, price: 29750.98, profit_percentage: 0.18335475558929185, profit: 183.35475558929184, capital: 15503.292035638382
# Entered position at index 5010, time 2022-06-04 11:38:00, price: 29739.28, positions: 0.03362556188313907, capital: 15686.646791227673
# Exited position at index 5362, time 2022-06-04 17:30:00, price: 29880.53, profit_percentage: 0.4749610615993393, profit: 474.9610615993393, capital: 16161.607852827012
# Entered position at index 5364, time 2022-06-04 17:32:00, price: 29763.52, positions: 0.03359817655976175, capital: 16636.568914426352
# Exited position at index 5418, time 2022-06-04 18:26:00, price: 29832.17, profit_percentage: 0.23065148208275707, profit: 230.65148208275707, capital: 16867.22039650911
# Entered position at index 5427, time 2022-06-04 18:35:00, price: 29802.89, positions: 0.03355379293753056, capital: 17097.871878591868
# Exited position at index 5812, time 2022-06-05 01:06:00, price: 29875.1, profit_percentage: 0.24229193880190522, profit: 242.29193880190522, capital: 17340.16381739377
# Entered position at index 5815, time 2022-06-05 01:09:00, price: 29876.03, positions: 0.03347164934564599, capital: 17582.455756195675
# Exited position at index 6476, time 2022-06-05 12:10:00, price: 29549.71, profit_percentage: -1.092246861447119, profit: -1092.2468614471188, capital: 16490.208894748557
# Entered position at index 6478, time 2022-06-05 12:12:00, price: 29514.58, positions: 0.03388155955463368, capital: 16490.208894748557
# Exited position at index 6479, time 2022-06-05 12:13:00, price: 29575.29, profit_percentage: 0.20569494805617808, profit: 205.6949480561781, capital: 16695.903842804735
# Entered position at index 6482, time 2022-06-05 12:16:00, price: 29586.36, positions: 0.033799358893760505, capital: 16901.598790860913
# Exited position at index 6509, time 2022-06-05 12:43:00, price: 29639.9, profit_percentage: 0.1809617675171967, profit: 180.9617675171967, capital: 17082.56055837811
# Entered position at index 6511, time 2022-06-05 12:45:00, price: 29632.4, positions: 0.03374684467002335, capital: 17263.52232589531
# Exited position at index 6643, time 2022-06-05 14:57:00, price: 29701.53, profit_percentage: 0.23329193720386257, profit: 233.29193720386257, capital: 17496.81426309917
# Entered position at index 6659, time 2022-06-05 15:13:00, price: 29672.53, positions: 0.03370120444734574, capital: 17730.106200303035
# Exited position at index 6673, time 2022-06-05 15:27:00, price: 29757.15, profit_percentage: 0.2851795920334485, profit: 285.1795920334485, capital: 18015.285792336483
# Entered position at index 6675, time 2022-06-05 15:29:00, price: 29734.03, positions: 0.03363149899290476, capital: 18300.46538436993
# Exited position at index 6820, time 2022-06-05 17:54:00, price: 29788.9, profit_percentage: 0.18453603497407725, profit: 184.5360349740772, capital: 18485.001419344007
# Entered position at index 6823, time 2022-06-05 17:57:00, price: 29787.9, positions: 0.03357067802698411, capital: 18669.537454318084
# Exited position at index 6849, time 2022-06-05 18:23:00, price: 29837.88, profit_percentage: 0.1677862487788651, profit: 167.78624877886512, capital: 18837.32370309695
# Entered position at index 6851, time 2022-06-05 18:25:00, price: 29818.38, positions: 0.033536362471737226, capital: 19005.109951875816
# Exited position at index 6867, time 2022-06-05 18:41:00, price: 29883.72, profit_percentage: 0.21912659239033153, profit: 219.12659239033152, capital: 19224.236544266147
# Entered position at index 6869, time 2022-06-05 18:43:00, price: 29859.72, positions: 0.033489932256565026, capital: 19443.363136656477
# Exited position at index 6881, time 2022-06-05 18:55:00, price: 29920.23, profit_percentage: 0.20264758008446965, profit: 202.64758008446958, capital: 19646.010716740948
# Entered position at index 6884, time 2022-06-05 18:58:00, price: 29901.23, positions: 0.03344344028657015, capital: 19848.65829682542
# Exited position at index 6891, time 2022-06-05 19:05:00, price: 30080.48, profit_percentage: 0.59947366713677, profit: 599.4736671367699, capital: 20448.131963962187
# Entered position at index 6894, time 2022-06-05 19:08:00, price: 30042.89, positions: 0.03328574581207068, capital: 21047.605631098955
# Exited position at index 6896, time 2022-06-05 19:10:00, price: 30092.88, profit_percentage: 0.16639544331454664, profit: 166.39544331454664, capital: 21214.001074413503
# Entered position at index 6897, time 2022-06-05 19:11:00, price: 30071.38, positions: 0.03325421048186016, capital: 21380.39651772805
# Exited position at index 6917, time 2022-06-05 19:31:00, price: 29757.61, profit_percentage: -1.0434173622893277, profit: -1043.4173622893277, capital: 20336.979155438723
# Entered position at index 6919, time 2022-06-05 19:33:00, price: 29736.55, positions: 0.033628648918586725, capital: 20336.979155438723
# Exited position at index 6921, time 2022-06-05 19:35:00, price: 29794.89, profit_percentage: 0.19618953779103546, profit: 196.18953779103546, capital: 20533.16869322976
# Entered position at index 6923, time 2022-06-05 19:37:00, price: 29789.65, positions: 0.03356870590960283, capital: 20729.358231020797
# Exited position at index 6949, time 2022-06-05 20:03:00, price: 29861.79, profit_percentage: 0.24216464443187286, profit: 242.16464443187283, capital: 20971.52287545267
# Entered position at index 6953, time 2022-06-05 20:07:00, price: 29877.03, positions: 0.033470529031834825, capital: 21213.68751988454
# Exited position at index 6964, time 2022-06-05 20:18:00, price: 29926.44, profit_percentage: 0.16537788394629538, profit: 165.37788394629538, capital: 21379.065403830835
# Entered position at index 6967, time 2022-06-05 20:21:00, price: 29925.7, positions: 0.03341609385912443, capital: 21544.44328777713
# Exited position at index 6969, time 2022-06-05 20:23:00, price: 29983.9, profit_percentage: 0.19448166626010663, profit: 194.48166626010664, capital: 21738.924954037237
# Entered position at index 6972, time 2022-06-05 20:26:00, price: 30075.24, positions: 0.03324994247759951, capital: 21933.406620297344
# Exited position at index 7408, time 2022-06-06 03:48:00, price: 30171.21, profit_percentage: 0.3190996979575143, profit: 319.0996979575143, capital: 22252.50631825486
# Entered position at index 7412, time 2022-06-06 03:52:00, price: 30247.17, positions: 0.033060944213954564, capital: 22571.606016212372
# Exited position at index 7421, time 2022-06-06 04:01:00, price: 30330.7, profit_percentage: 0.2761580670191706, profit: 276.15806701917063, capital: 22847.764083231545
# Entered position at index 7427, time 2022-06-06 04:07:00, price: 30376.38, positions: 0.03292031506058326, capital: 23123.922150250713
# Exited position at index 7436, time 2022-06-06 04:16:00, price: 30462.45, profit_percentage: 0.28334515172643915, profit: 283.34515172643916, capital: 23407.267301977154
# Entered position at index 7441, time 2022-06-06 04:21:00, price: 30489.63, positions: 0.03279803657833827, capital: 23690.612453703594
# Exited position at index 7445, time 2022-06-06 04:25:00, price: 30543.79, profit_percentage: 0.1776341661082796, profit: 177.63416610827957, capital: 23868.246619811875
# Entered position at index 7447, time 2022-06-06 04:27:00, price: 30601.83, positions: 0.03267778430244204, capital: 24045.880785920155
# Exited position at index 7470, time 2022-06-06 04:50:00, price: 30745.63, profit_percentage: 0.46990653826911416, profit: 469.9065382691141, capital: 24515.78732418927
# Entered position at index 7475, time 2022-06-06 04:55:00, price: 30834.68, positions: 0.0324310159858964, capital: 24985.693862458385
# Exited position at index 7482, time 2022-06-06 05:02:00, price: 30923.65, profit_percentage: 0.28853874922652406, profit: 288.53874922652403, capital: 25274.23261168491
# Entered position at index 7486, time 2022-06-06 05:06:00, price: 30860.49, positions: 0.032403892485180885, capital: 25562.771360911436
# Exited position at index 7492, time 2022-06-06 05:12:00, price: 30919.0, profit_percentage: 0.1895951749307882, profit: 189.59517493078818, capital: 25752.366535842226
# Entered position at index 7496, time 2022-06-06 05:16:00, price: 30902.65, positions: 0.032359684363638716, capital: 25941.961710773016
# Exited position at index 7510, time 2022-06-06 05:30:00, price: 31040.87, profit_percentage: 0.4472755572742063, profit: 447.2755572742063, capital: 26389.23726804722
# Entered position at index 7513, time 2022-06-06 05:33:00, price: 31054.62, positions: 0.03220132785395539, capital: 26836.512825321428
# Exited position at index 7587, time 2022-06-06 06:47:00, price: 31155.61, profit_percentage: 0.3252012099971006, profit: 325.20120999710065, capital: 27161.714035318528
# Entered position at index 7590, time 2022-06-06 06:50:00, price: 31168.11, positions: 0.03208407567863435, capital: 27486.915245315628
# Exited position at index 7598, time 2022-06-06 06:58:00, price: 31232.59, profit_percentage: 0.20687811997583289, profit: 206.87811997583285, capital: 27693.79336529146
# Entered position at index 7601, time 2022-06-06 07:01:00, price: 31210.63, positions: 0.032040365734366784, capital: 27900.671485267296
# Exited position at index 7604, time 2022-06-06 07:04:00, price: 31276.95, profit_percentage: 0.21249170555031957, profit: 212.49170555031958, capital: 28113.163190817617
# Entered position at index 7607, time 2022-06-06 07:07:00, price: 31183.04, positions: 0.03206871427545229, capital: 28325.654896367938
# Exited position at index 7629, time 2022-06-06 07:29:00, price: 31242.78, profit_percentage: 0.19157849908154548, profit: 191.57849908154546, capital: 28517.233395449482
# Entered position at index 7634, time 2022-06-06 07:34:00, price: 31212.8, positions: 0.03203813819971294, capital: 28708.811894531027
# Exited position at index 7767, time 2022-06-06 09:47:00, price: 31275.42, profit_percentage: 0.20062282140659915, profit: 200.62282140659917, capital: 28909.434715937627
# Entered position at index 7771, time 2022-06-06 09:51:00, price: 31279.51, positions: 0.031969810268766996, capital: 29110.057537344226
# Exited position at index 7773, time 2022-06-06 09:53:00, price: 31354.94, profit_percentage: 0.24114827885731038, profit: 241.14827885731037, capital: 29351.20581620154
# Entered position at index 7775, time 2022-06-06 09:55:00, price: 31283.43, positions: 0.0319658042612335, capital: 29592.35409505885
# Exited position at index 7784, time 2022-06-06 10:04:00, price: 31342.29, profit_percentage: 0.18815072388162227, profit: 188.15072388162224, capital: 29780.504818940473
# Entered position at index 7786, time 2022-06-06 10:06:00, price: 31281.08, positions: 0.031968205701337675, capital: 29968.655542822096
# Exited position at index 7851, time 2022-06-06 11:11:00, price: 31346.08, profit_percentage: 0.20779333705869488, profit: 207.7933370586949, capital: 30176.44887988079
# Entered position at index 7853, time 2022-06-06 11:13:00, price: 31333.61, positions: 0.03191461181778927, capital: 30384.242216939485
# Exited position at index 7865, time 2022-06-06 11:25:00, price: 31392.79, profit_percentage: 0.18887067273767782, profit: 188.8706727376778, capital: 30573.112889677162
# Entered position at index 7869, time 2022-06-06 11:29:00, price: 31416.18, positions: 0.0318307318076227, capital: 30761.98356241484
# Exited position at index 8005, time 2022-06-06 13:45:00, price: 31476.65, profit_percentage: 0.19248043524069813, profit: 192.48043524069814, capital: 30954.463997655537
# Entered position at index 8009, time 2022-06-06 13:49:00, price: 31486.98, positions: 0.031759158865029294, capital: 31146.944432896235
# Exited position at index 8026, time 2022-06-06 14:06:00, price: 31553.0, profit_percentage: 0.2096739668269248, profit: 209.67396682692478, capital: 31356.61839972316
# Entered position at index 8028, time 2022-06-06 14:08:00, price: 31462.5, positions: 0.03178386968613429, capital: 31566.292366550086
# Exited position at index 8205, time 2022-06-06 17:05:00, price: 31593.52, profit_percentage: 0.41643226062773286, profit: 416.43226062773283, capital: 31982.72462717782
# Entered position at index 8210, time 2022-06-06 17:10:00, price: 31560.37, positions: 0.03168530660445362, capital: 32399.156887805555
# Exited position at index 8227, time 2022-06-06 17:27:00, price: 31699.78, profit_percentage: 0.4417248593726875, profit: 441.72485937268743, capital: 32840.881747178246
# Entered position at index 8229, time 2022-06-06 17:29:00, price: 31659.18, positions: 0.03158641506191885, capital: 33282.60660655094
# Exited position at index 8271, time 2022-06-06 18:11:00, price: 31300.84, profit_percentage: -1.1318675973288004, profit: -1131.8675973288005, capital: 32150.739009222136
# Entered position at index 8273, time 2022-06-06 18:13:00, price: 31331.08, positions: 0.03191718893826832, capital: 32150.739009222136
# Exited position at index 8304, time 2022-06-06 18:44:00, price: 31424.09, profit_percentage: 0.2968617743148286, profit: 296.86177431482855, capital: 32447.600783536964
# Entered position at index 8307, time 2022-06-06 18:47:00, price: 31370.55, positions: 0.03187703116457952, capital: 32744.46255785179
# Exited position at index 8312, time 2022-06-06 18:52:00, price: 31455.81, profit_percentage: 0.27178356770921147, profit: 271.7835677092114, capital: 33016.246125561
# Entered position at index 8315, time 2022-06-06 18:55:00, price: 31481.43, positions: 0.031764757827074566, capital: 33288.02969327021
# Exited position at index 8397, time 2022-06-06 20:17:00, price: 31096.0, profit_percentage: -1.2243090609289358, profit: -1224.3090609289359, capital: 32063.720632341276
# Entered position at index 8398, time 2022-06-06 20:18:00, price: 31078.5, positions: 0.03217658509902344, capital: 32063.720632341276
# Exited position at index 8404, time 2022-06-06 20:24:00, price: 31160.38, profit_percentage: 0.26346187879080724, profit: 263.46187879080725, capital: 32327.182511132083
# Entered position at index 8408, time 2022-06-06 20:28:00, price: 31204.53, positions: 0.03204662912724531, capital: 32590.64438992289
# Exited position at index 8423, time 2022-06-06 20:43:00, price: 31266.24, profit_percentage: 0.19775974834423965, profit: 197.75974834423968, capital: 32788.40413826713
# Entered position at index 8426, time 2022-06-06 20:46:00, price: 31255.54, positions: 0.03199432804552409, capital: 32986.163886611364
# Exited position at index 8430, time 2022-06-06 20:50:00, price: 31307.5, profit_percentage: 0.16624252852454036, profit: 166.24252852454035, capital: 33152.406415135905
# Entered position at index 8433, time 2022-06-06 20:53:00, price: 31301.63, positions: 0.03194721808417006, capital: 33318.648943660446
# Exited position at index 8485, time 2022-06-06 21:45:00, price: 31361.88, profit_percentage: 0.1924819889571246, profit: 192.4819889571246, capital: 33511.13093261757
# Entered position at index 8489, time 2022-06-06 21:49:00, price: 31306.6, positions: 0.031942146384468455, capital: 33703.61292157469
# Exited position at index 8542, time 2022-06-06 22:42:00, price: 31360.61, profit_percentage: 0.17251953262252062, profit: 172.51953262252061, capital: 33876.13245419721
# Entered position at index 8549, time 2022-06-06 22:49:00, price: 31386.94, positions: 0.03186038524303421, capital: 34048.651986819736
# Exited position at index 8555, time 2022-06-06 22:55:00, price: 31445.53, profit_percentage: 0.18666999713893787, profit: 186.66999713893787, capital: 34235.321983958675
# Entered position at index 8558, time 2022-06-06 22:58:00, price: 31417.73, positions: 0.031829161432095826, capital: 34421.99198109761
# Exited position at index 8579, time 2022-06-06 23:19:00, price: 31489.61, profit_percentage: 0.22878801237390806, profit: 228.78801237390803, capital: 34650.77999347152
# Entered position at index 8582, time 2022-06-06 23:22:00, price: 31381.11, positions: 0.031866304283054356, capital: 34879.56800584543
# Exited position at index 8616, time 2022-06-06 23:56:00, price: 31433.17, profit_percentage: 0.1658959800975736, profit: 165.89598009757356, capital: 35045.463985943
# Entered position at index 8617, time 2022-06-06 23:57:00, price: 31450.49, positions: 0.03179600699384969, capital: 35211.359966040574
# Exited position at index 8633, time 2022-06-07 00:19:00, price: 31512.0, profit_percentage: 0.19557723901916438, profit: 195.57723901916438, capital: 35406.93720505974
# Entered position at index 8636, time 2022-06-07 00:22:00, price: 31500.16, positions: 0.03174587049716573, capital: 35602.5144440789
# Exited position at index 8813, time 2022-06-07 03:19:00, price: 31147.99, profit_percentage: -1.11799432129868, profit: -1117.99432129868, capital: 34484.52012278022
# Entered position at index 8817, time 2022-06-07 03:23:00, price: 30722.58, positions: 0.03254934969654241, capital: 34484.52012278022
# Exited position at index 8821, time 2022-06-07 03:27:00, price: 30785.38, profit_percentage: 0.20440991609428394, profit: 204.40991609428397, capital: 34688.9300388745
# Entered position at index 8826, time 2022-06-07 03:32:00, price: 30577.46, positions: 0.032703828244726674, capital: 34893.33995496879
# Exited position at index 8846, time 2022-06-07 03:52:00, price: 30214.89, profit_percentage: -1.1857427006690542, profit: -1185.742700669054, capital: 33707.59725429973
# Entered position at index 8848, time 2022-06-07 03:54:00, price: 30242.37, positions: 0.033066191571626165, capital: 33707.59725429973
# Exited position at index 8879, time 2022-06-07 04:25:00, price: 29900.57, profit_percentage: -1.13020242791818, profit: -1130.2024279181799, capital: 32577.394826381555
# Entered position at index 8880, time 2022-06-07 04:26:00, price: 29885.67, positions: 0.033460852642754876, capital: 32577.394826381555
# Exited position at index 8905, time 2022-06-07 04:51:00, price: 29516.29, profit_percentage: -1.235976974918071, profit: -1235.976974918071, capital: 31341.417851463484
# Entered position at index 8907, time 2022-06-07 04:53:00, price: 29426.69, positions: 0.03398275511109133, capital: 31341.417851463484
# Exited position at index 8911, time 2022-06-07 04:57:00, price: 29516.69, profit_percentage: 0.30584479599982195, profit: 305.84479599982194, capital: 31647.262647463307
# Entered position at index 8916, time 2022-06-07 05:02:00, price: 29361.38, positions: 0.034058344669085715, capital: 31953.10744346313
# Exited position at index 8917, time 2022-06-07 05:03:00, price: 29410.41, profit_percentage: 0.1669880639125233, profit: 166.9880639125233, capital: 32120.095507375652
# Entered position at index 8922, time 2022-06-07 05:08:00, price: 29353.75, positions: 0.034067197547161775, capital: 32287.083571288174
# Exited position at index 8926, time 2022-06-07 05:12:00, price: 29408.75, profit_percentage: 0.18736958650938976, profit: 187.36958650938976, capital: 32474.453157797565
# Entered position at index 8930, time 2022-06-07 05:16:00, price: 29424.28, positions: 0.03398553847366868, capital: 32661.822744306955
# Exited position at index 8995, time 2022-06-07 06:21:00, price: 29532.88, profit_percentage: 0.3690829478240493, profit: 369.0829478240493, capital: 33030.905692131004
# Entered position at index 8997, time 2022-06-07 06:23:00, price: 29500.4, positions: 0.033897845452943005, capital: 33399.98863995505
# Exited position at index 8999, time 2022-06-07 06:25:00, price: 29580.92, profit_percentage: 0.2729454515870863, profit: 272.9454515870862, capital: 33672.93409154214
# Entered position at index 9003, time 2022-06-07 06:29:00, price: 29544.44, positions: 0.0338473161109163, capital: 33945.87954312923
# Exited position at index 9005, time 2022-06-07 06:31:00, price: 29594.94, profit_percentage: 0.17092894636012734, profit: 170.92894636012733, capital: 34116.80848948936
# Entered position at index 9010, time 2022-06-07 06:36:00, price: 29592.22, positions: 0.033792665774990856, capital: 34287.73743584949
# Exited position at index 9312, time 2022-06-07 11:38:00, price: 29644.65, profit_percentage: 0.17717494665827804, profit: 177.17494665827803, capital: 34464.91238250777
# Entered position at index 9317, time 2022-06-07 11:43:00, price: 29690.03, positions: 0.03368134016705271, capital: 34642.08732916605
# Exited position at index 9464, time 2022-06-07 14:10:00, price: 29360.89, profit_percentage: -1.108587630258371, profit: -1108.587630258371, capital: 33533.499698907675
# Entered position at index 9465, time 2022-06-07 14:11:00, price: 29383.55, positions: 0.03403264751876475, capital: 33533.499698907675
# Exited position at index 9469, time 2022-06-07 14:15:00, price: 29443.5, profit_percentage: 0.20402572187499715, profit: 204.02572187499715, capital: 33737.52542078267
# Entered position at index 9472, time 2022-06-07 14:18:00, price: 29498.46, positions: 0.03390007478356497, capital: 33941.55114265767
# Exited position at index 9608, time 2022-06-07 16:34:00, price: 29568.99, profit_percentage: 0.23909722744849216, profit: 239.09722744849216, capital: 34180.648370106166
# ...
# Exited position at index 39860, time 2022-06-29 01:20:00, price: 20403.94, profit_percentage: 0.18683200194049596, profit: 186.83200194049599, capital: 340281.3754369684
# Entered position at index 39864, time 2022-06-29 01:24:00, price: 20393.0, positions: 0.0490364340705144, capital: 340468.2074389089
# Exited position at index 39972, time 2022-06-29 03:12:00, price: 20159.83, profit_percentage: -1.1433825332221754, profit: -1143.3825332221757, capital: 339324.8249056867
# Entered position at index 39973, time 2022-06-29 03:13:00, price: 20215.33, positions: 0.04946740913949957, capital: 339324.8249056867
# Exited position at index 39975, time 2022-06-29 03:15:00, price: 20250.83, profit_percentage: 0.1756093024452235, profit: 175.60930244522345, capital: 339500.4342081319
# Entered position at index 39976, time 2022-06-29 03:16:00, price: 20287.68, positions: 0.049290998280729977, capital: 339676.0435105771
# Exited position at index 39989, time 2022-06-29 03:29:00, price: 20329.92, profit_percentage: 0.2082051767377934, profit: 208.2051767377934, capital: 339884.2486873149
# Entered position at index 39995, time 2022-06-29 03:35:00, price: 20311.83, positions: 0.049232393142321494, capital: 340092.4538640527
# Exited position at index 40075, time 2022-06-29 04:55:00, price: 20349.71, profit_percentage: 0.18649230522310092, profit: 186.4923052231009, capital: 340278.9461692758
# Entered position at index 40078, time 2022-06-29 04:58:00, price: 20339.71, positions: 0.049164909430862096, capital: 340465.43847449886
# Exited position at index 40309, time 2022-06-29 08:49:00, price: 20080.93, profit_percentage: -1.2722895262518437, profit: -1272.2895262518437, capital: 339193.148948247
# Entered position at index 40310, time 2022-06-29 08:50:00, price: 20044.21, positions: 0.04988971877664423, capital: 339193.148948247
# Exited position at index 40314, time 2022-06-29 08:54:00, price: 20108.57, profit_percentage: 0.3210902300464852, profit: 321.09023004648515, capital: 339514.2391782935
# Entered position at index 40317, time 2022-06-29 08:57:00, price: 20158.58, positions: 0.04960666872368986, capital: 339835.32940834
# Exited position at index 40371, time 2022-06-29 09:51:00, price: 19947.7, profit_percentage: -1.0461054300451769, profit: -1046.1054300451767, capital: 338789.2239782948
# Entered position at index 40372, time 2022-06-29 09:52:00, price: 19926.08, positions: 0.05018548555460983, capital: 338789.2239782948
# Exited position at index 40373, time 2022-06-29 09:53:00, price: 19965.58, profit_percentage: 0.19823266794070882, profit: 198.23266794070884, capital: 338987.45664623554
# Entered position at index 40376, time 2022-06-29 09:56:00, price: 19909.02, positions: 0.05022848939827274, capital: 339185.68931417627
# Exited position at index 40384, time 2022-06-29 10:04:00, price: 19967.5, profit_percentage: 0.29373620600109684, profit: 293.7362060010968, capital: 339479.42552017735
# Entered position at index 40390, time 2022-06-29 10:10:00, price: 19923.21, positions: 0.050192714928969775, capital: 339773.1617261784
# Exited position at index 40395, time 2022-06-29 10:15:00, price: 19968.21, profit_percentage: 0.225867217180364, profit: 225.867217180364, capital: 339999.0289433588
# Entered position at index 40400, time 2022-06-29 10:20:00, price: 19978.85, positions: 0.05005293097450554, capital: 340224.8961605392
# Exited position at index 40403, time 2022-06-29 10:23:00, price: 20017.62, profit_percentage: 0.19405521338816017, profit: 194.05521338816015, capital: 340418.95137392735
# Entered position at index 40408, time 2022-06-29 10:28:00, price: 20033.18, positions: 0.04991718738612641, capital: 340613.0065873155
# Exited position at index 40425, time 2022-06-29 10:45:00, price: 20094.21, profit_percentage: 0.3046445946175237, profit: 304.6445946175237, capital: 340917.65118193306
# Entered position at index 40443, time 2022-06-29 11:03:00, price: 20081.91, positions: 0.049796060235306305, capital: 341222.2957765506
# Exited position at index 40528, time 2022-06-29 12:28:00, price: 20137.71, profit_percentage: 0.27786201611300554, profit: 277.86201611300555, capital: 341500.1577926636
# Entered position at index 40532, time 2022-06-29 12:32:00, price: 20116.72, positions: 0.04970989306407803, capital: 341778.0198087766
# Exited position at index 40637, time 2022-06-29 14:17:00, price: 19907.23, profit_percentage: -1.0413725497993787, profit: -1041.3725497993787, capital: 340736.64725897723
# Entered position at index 40640, time 2022-06-29 14:20:00, price: 19884.89, positions: 0.050289440876967385, capital: 340736.64725897723
# Exited position at index 40644, time 2022-06-29 14:24:00, price: 19958.37, profit_percentage: 0.36952681156395417, profit: 369.52681156395414, capital: 341106.17407054116
# Entered position at index 40647, time 2022-06-29 14:27:00, price: 19981.21, positions: 0.05004701917451446, capital: 341475.7008821051
# Exited position at index 40651, time 2022-06-29 14:31:00, price: 20025.95, profit_percentage: 0.22391036378678572, profit: 223.9103637867857, capital: 341699.6112458919
# Entered position at index 40660, time 2022-06-29 14:40:00, price: 20023.71, positions: 0.04994079518730545, capital: 341923.5216096787
# Exited position at index 40669, time 2022-06-29 14:49:00, price: 20057.24, profit_percentage: 0.16745148626304754, profit: 167.45148626304754, capital: 342090.97309594176
# Entered position at index 40673, time 2022-06-29 14:53:00, price: 19999.21, positions: 0.05000197507801558, capital: 342258.42458220484
# Exited position at index 40678, time 2022-06-29 14:58:00, price: 20068.46, profit_percentage: 0.34626367741525793, profit: 346.26367741525786, capital: 342604.6882596201
# Entered position at index 40680, time 2022-06-29 15:00:00, price: 20094.18, positions: 0.04976565353749195, capital: 342950.95193703537
# Exited position at index 40782, time 2022-06-29 16:42:00, price: 19888.89, profit_percentage: -1.0216391014711768, profit: -1021.6391014711766, capital: 341929.3128355642
# Entered position at index 40783, time 2022-06-29 16:43:00, price: 19906.28, positions: 0.05023540309892155, capital: 341929.3128355642
# Exited position at index 40789, time 2022-06-29 16:49:00, price: 19958.66, profit_percentage: 0.26313304143215616, profit: 263.13304143215623, capital: 342192.4458769963
# Entered position at index 40793, time 2022-06-29 16:53:00, price: 20072.56, positions: 0.049819255740174644, capital: 342455.57891842845
# Exited position at index 40808, time 2022-06-29 17:08:00, price: 20114.96, profit_percentage: 0.2112336443383296, profit: 211.23364433832964, capital: 342666.8125627668
# Entered position at index 40817, time 2022-06-29 17:17:00, price: 20049.46, positions: 0.04987665503210561, capital: 342878.0462071051
# Exited position at index 40825, time 2022-06-29 17:25:00, price: 20087.46, profit_percentage: 0.18953128912200132, profit: 189.5312891220013, capital: 343067.5774962271
# Entered position at index 40832, time 2022-06-29 17:32:00, price: 20097.96, positions: 0.04975629367358677, capital: 343257.1087853491
# Exited position at index 40850, time 2022-06-29 17:50:00, price: 20137.2, profit_percentage: 0.19524369637516245, profit: 195.24369637516244, capital: 343452.3524817243
# Entered position at index 40859, time 2022-06-29 17:59:00, price: 20102.71, positions: 0.049744536930592935, capital: 343647.59617809945
# Exited position at index 41151, time 2022-06-29 22:51:00, price: 20180.8, profit_percentage: 0.388455088891001, profit: 388.45508889100097, capital: 344036.0512669904
# Entered position at index 41160, time 2022-06-29 23:00:00, price: 20287.96, positions: 0.04929031800141562, capital: 344424.5063558814
# Exited position at index 41166, time 2022-06-29 23:06:00, price: 20398.01, profit_percentage: 0.5424399496055753, profit: 542.4399496055753, capital: 344966.94630548696
# Entered position at index 41168, time 2022-06-29 23:08:00, price: 20370.49, positions: 0.0490906207950815, capital: 345509.3862550925
# Exited position at index 41194, time 2022-06-29 23:34:00, price: 20165.11, profit_percentage: -1.0082231698893889, profit: -1008.2231698893888, capital: 344501.1630852031
# Entered position at index 41199, time 2022-06-29 23:39:00, price: 20085.21, positions: 0.04978787874261708, capital: 344501.1630852031
# Exited position at index 41206, time 2022-06-29 23:46:00, price: 20118.7, profit_percentage: 0.16673960590903258, profit: 166.73960590903255, capital: 344667.90269111213
# Entered position at index 41208, time 2022-06-29 23:48:00, price: 20109.71, positions: 0.049727221327408505, capital: 344834.6422970212
# Exited position at index 41216, time 2022-06-29 23:56:00, price: 20145.46, profit_percentage: 0.1777748162454854, profit: 177.77481624548543, capital: 345012.41711326665
# Entered position at index 41220, time 2022-06-30 00:06:00, price: 20191.39, positions: 0.04952606036533394, capital: 345190.19192951213
# Exited position at index 41223, time 2022-06-30 00:09:00, price: 20233.46, profit_percentage: 0.20835613595695845, profit: 208.35613595695844, capital: 345398.5480654691
# Entered position at index 41227, time 2022-06-30 00:13:00, price: 20268.19, positions: 0.04933839676853237, capital: 345606.904201426
# Exited position at index 41252, time 2022-06-30 00:38:00, price: 20313.21, profit_percentage: 0.22212146225193485, profit: 222.12146225193487, capital: 345829.02566367795
# Entered position at index 41262, time 2022-06-30 00:48:00, price: 20295.46, positions: 0.04927210321914359, capital: 346051.1471259299
# Exited position at index 41342, time 2022-06-30 02:08:00, price: 20068.89, profit_percentage: -1.116358042636135, profit: -1116.358042636135, capital: 344934.78908329376
# Entered position at index 41343, time 2022-06-30 02:09:00, price: 20094.89, positions: 0.04976389519922727, capital: 344934.78908329376
# Exited position at index 41406, time 2022-06-30 03:12:00, price: 20129.07, profit_percentage: 0.17009299379096024, profit: 170.09299379096026, capital: 345104.88207708474
# Entered position at index 41412, time 2022-06-30 03:18:00, price: 20067.96, positions: 0.04983067536510936, capital: 345274.9750708757
# Exited position at index 41783, time 2022-06-30 09:29:00, price: 19773.47, profit_percentage: -1.4674635588270954, profit: -1467.4635588270953, capital: 343807.5115120486
# Entered position at index 41785, time 2022-06-30 09:31:00, price: 19503.89, positions: 0.05127182321065182, capital: 343807.5115120486
# Exited position at index 41791, time 2022-06-30 09:37:00, price: 19537.02, profit_percentage: 0.16986355029689473, profit: 169.86355029689472, capital: 343977.37506234547
# Entered position at index 41801, time 2022-06-30 09:47:00, price: 19462.86, positions: 0.05137991024957277, capital: 344147.23861264234
# Exited position at index 41898, time 2022-06-30 11:24:00, price: 19224.26, profit_percentage: -1.2259246585548176, profit: -1225.9246585548176, capital: 342921.3139540875
# Entered position at index 41899, time 2022-06-30 11:25:00, price: 19302.16, positions: 0.05180767333811346, capital: 342921.3139540875
# Exited position at index 41941, time 2022-06-30 12:07:00, price: 19102.46, profit_percentage: -1.0345992365621295, profit: -1034.5992365621296, capital: 341886.71471752535
# Entered position at index 41943, time 2022-06-30 12:09:00, price: 19011.96, positions: 0.052598469594928664, capital: 341886.71471752535
# Exited position at index 41948, time 2022-06-30 12:14:00, price: 19056.89, profit_percentage: 0.23632492389001605, profit: 236.32492389001604, capital: 342123.03964141535
# Entered position at index 41953, time 2022-06-30 12:19:00, price: 19021.96, positions: 0.05257081814912869, capital: 342359.36456530535
# Exited position at index 41981, time 2022-06-30 12:47:00, price: 19088.54, profit_percentage: 0.350016507236908, profit: 350.01650723690796, capital: 342709.3810725423
# Entered position at index 41985, time 2022-06-30 12:51:00, price: 19063.46, positions: 0.05245637465601733, capital: 343059.3975797792
# Exited position at index 41987, time 2022-06-30 12:53:00, price: 19141.19, profit_percentage: 0.4077434002012204, profit: 407.7434002012204, capital: 343467.1409799804
# Entered position at index 41996, time 2022-06-30 13:02:00, price: 19093.12, positions: 0.052374886870244365, capital: 343874.8843801816
# Exited position at index 42004, time 2022-06-30 13:10:00, price: 19142.23, profit_percentage: 0.2572130694197731, profit: 257.21306941977315, capital: 344132.0974496014
# Entered position at index 42006, time 2022-06-30 13:12:00, price: 19114.26, positions: 0.05231696126347554, capital: 344389.3105190212
# Exited position at index 42144, time 2022-06-30 15:30:00, price: 19173.16, profit_percentage: 0.3081469018418786, profit: 308.14690184187856, capital: 344697.45742086304
# Entered position at index 42148, time 2022-06-30 15:34:00, price: 19221.56, positions: 0.05202491369066818, capital: 345005.6043227049
# Exited position at index 42159, time 2022-06-30 15:45:00, price: 19267.96, profit_percentage: 0.24139559952468903, profit: 241.39559952468898, capital: 345246.99992222956
# Entered position at index 42162, time 2022-06-30 15:48:00, price: 19222.96, positions: 0.05202112473833375, capital: 345488.3955217542
# Exited position at index 42215, time 2022-06-30 16:41:00, price: 18987.47, profit_percentage: -1.2250454664630106, profit: -1225.0454664630108, capital: 344263.3500552912
# Entered position at index 42217, time 2022-06-30 16:43:00, price: 18934.4, positions: 0.05281392597600135, capital: 344263.3500552912
# Exited position at index 42266, time 2022-06-30 17:32:00, price: 19007.3, profit_percentage: 0.3850135203650383, profit: 385.0135203650383, capital: 344648.36357565626
# Entered position at index 42271, time 2022-06-30 17:37:00, price: 19011.35, positions: 0.05260015727447026, capital: 345033.3770960213
# Exited position at index 42285, time 2022-06-30 17:51:00, price: 19048.96, profit_percentage: 0.1978291915092857, profit: 197.8291915092857, capital: 345231.2062875306
# Entered position at index 42289, time 2022-06-30 17:55:00, price: 19081.48, positions: 0.0524068363669904, capital: 345429.0354790399
# Exited position at index 42300, time 2022-06-30 18:06:00, price: 19125.21, profit_percentage: 0.22917509543284673, profit: 229.17509543284672, capital: 345658.21057447273
# Entered position at index 42303, time 2022-06-30 18:09:00, price: 19139.46, positions: 0.052248078054448775, capital: 345887.3856699056
# Exited position at index 42318, time 2022-06-30 18:24:00, price: 19172.0, profit_percentage: 0.17001524598918086, profit: 170.01524598918087, capital: 346057.4009158948
# Entered position at index 42324, time 2022-06-30 18:30:00, price: 19199.21, positions: 0.05208547643366576, capital: 346227.416161884
# Exited position at index 42506, time 2022-06-30 21:32:00, price: 18987.21, profit_percentage: -1.1042121003937142, profit: -1104.2121003937143, capital: 345123.20406149025
# Entered position at index 42507, time 2022-06-30 21:33:00, price: 18995.33, positions: 0.05264451841584221, capital: 345123.20406149025
# Exited position at index 42513, time 2022-06-30 21:39:00, price: 19034.21, profit_percentage: 0.20468188760078068, profit: 204.68188760078073, capital: 345327.88594909105
# Entered position at index 42518, time 2022-06-30 21:44:00, price: 18958.71, positions: 0.05274620477870066, capital: 345532.56783669186
# Exited position at index 42520, time 2022-06-30 21:46:00, price: 18990.86, profit_percentage: 0.1695790483635303, profit: 169.5790483635303, capital: 345702.1468850554
# Entered position at index 42535, time 2022-06-30 22:01:00, price: 18960.96, positions: 0.05273994565675999, capital: 345871.72593341896
# Exited position at index 42571, time 2022-06-30 22:37:00, price: 18993.96, profit_percentage: 0.174041820667308, profit: 174.04182066730795, capital: 346045.7677540863
# Entered position at index 42574, time 2022-06-30 22:40:00, price: 18962.21, positions: 0.05273646900862294, capital: 346219.8095747536
# Precision: 0.4515
# Recall: 1.0000
# F1 Score: 0.6221
# Accuracy: 0.8619

# %%
#Backtesting
# Install Required Packages
# !pip install MetaTrader5 pandas numpy torch matplotlib scikit-learn

# Imports and Model Definition
import MetaTrader5 as mt5
import pandas as pd
import datetime
import torch
import torch.nn as nn
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import time

# Define the RNN model with batch normalization and 15 activation layers
class BitcoinPriceLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size, dropout=0.5):
        super(BitcoinPriceLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, hidden_size)
        self.fc4 = nn.Linear(hidden_size, hidden_size)
        self.fc5 = nn.Linear(hidden_size, hidden_size)
        self.fc6 = nn.Linear(hidden_size, hidden_size)
        self.fc7 = nn.Linear(hidden_size, hidden_size)
        self.fc8 = nn.Linear(hidden_size, hidden_size)
        self.fc9 = nn.Linear(hidden_size, hidden_size)
        self.fc10 = nn.Linear(hidden_size, hidden_size)
        self.fc11 = nn.Linear(hidden_size, hidden_size)
        self.fc12 = nn.Linear(hidden_size, hidden_size)
        self.fc13 = nn.Linear(hidden_size, hidden_size)
        self.fc14 = nn.Linear(hidden_size, hidden_size)
        self.fc15 = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.dropout(out[:, -1, :])
        out = torch.relu(self.fc1(out))
        out = torch.relu(self.fc2(out))
        out = torch.relu(self.fc3(out))
        out = torch.relu(self.fc4(out))
        out = torch.relu(self.fc5(out))
        out = torch.relu(self.fc6(out))
        out = torch.relu(self.fc7(out))
        out = torch.relu(self.fc8(out))
        out = torch.relu(self.fc9(out))
        out = torch.relu(self.fc10(out))
        out = torch.relu(self.fc11(out))
        out = torch.relu(self.fc12(out))
        out = torch.relu(self.fc13(out))
        out = torch.relu(self.fc14(out))
        out = self.fc15(out)
        return out

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Running on device: {device}")

# Load the trained model
model_path = "C:/Users/gunne/Documents/PriceNeuralNetwork/ProfitBS0.5/005model.pth"
model = BitcoinPriceLSTM(input_size=10, hidden_size=512, num_layers=3, output_size=2, dropout=0.5).to(device)
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

# Connect to MetaTrader 5
if not mt5.initialize():
    print("initialize() failed")
    mt5.shutdown()
else:
    print("MetaTrader 5 initialized successfully")

# Login to the demo account
account = 51806647  # Ensure the account number is an integer
password = "lKDtOjEK6$rp@f"
server = "ICMarketsSC-Demo"

# Debug print for login details
print(f"Attempting to login with Account: {account}, Password: {password}, Server: {server}")

authorized = mt5.login(login=account, password=password, server=server)
if not authorized:
    print(f"Failed to connect to account #{account}, error code: {mt5.last_error()}")
else:
    print(f"Connected to account #{account}")
# Out:
# Requirement already satisfied: MetaTrader5 in c:\users\gunne\anaconda3\lib\site-packages (5.0.4288)
# Requirement already satisfied: pandas in c:\users\gunne\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\gunne\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: torch in c:\users\gunne\anaconda3\lib\site-packages (2.3.0+cu121)
# Requirement already satisfied: matplotlib in c:\users\gunne\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: scikit-learn in c:\users\gunne\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gunne\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gunne\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\gunne\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: filelock in c:\users\gunne\anaconda3\lib\site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\gunne\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in c:\users\gunne\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\gunne\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\gunne\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\gunne\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\gunne\anaconda3\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\gunne\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\gunne\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\gunne\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gunne\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\gunne\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Collecting tbb==2021.* (from mkl<=2021.4.0,>=2021.1.1->torch)
#   Obtaining dependency information for tbb==2021.* from https://files.pythonhosted.org/packages/7b/2d/1e1c70fae8ace27e6200fb71c2372a9aeac2baba474b1609d7d466e969b4/tbb-2021.12.0-py3-none-win_amd64.whl.metadata
#   Using cached tbb-2021.12.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in c:\users\gunne\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gunne\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\gunne\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Using cached tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
# Installing collected packages: tbb
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# Running on device: cuda
# MetaTrader 5 initialized successfully
# Attempting to login with Account: 51806647, Password: lKDtOjEK6$rp@f, Server: ICMarketsSC-Demo
# Connected to account #51806647
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
#Now lets do this with the dummy money traded with our account, part 2:

# Trading parameters
initial_capital = 1000
capital = initial_capital
leverage = 1  # No leverage used
profit_cap_percentage = 0.05
stop_loss_percentage = 1.0  # Stop loss at 1%
positions = 0
entry_price = None

# Trade log
trade_log = []

# Create a new folder for the current test
current_test_index = 0
base_log_dir = "trading_logs"
os.makedirs(base_log_dir, exist_ok=True)

# Find the next available folder index
while os.path.exists(os.path.join(base_log_dir, f"test_{current_test_index}")):
    current_test_index += 1

current_log_dir = os.path.join(base_log_dir, f"test_{current_test_index}")
os.makedirs(current_log_dir)

log_file_path = os.path.join(current_log_dir, "trade_log.txt")
log_csv_path = os.path.join(current_log_dir, "trade_log.csv")
iteration_csv_path = os.path.join(current_log_dir, "iteration_log.csv")

# DataFrames for logs
trade_log_df = pd.DataFrame(columns=['time', 'action', 'price', 'positions', 'capital', 'profit_percentage', 'profit'])
iteration_log_df = pd.DataFrame(columns=['time', 'price', 'positions', 'capital'])

def validate_volume(raw_volume, symbol):
    # Adjust the volume to match the broker's requirements
    min_volume = mt5.symbol_info(symbol).volume_min
    max_volume = mt5.symbol_info(symbol).volume_max
    step_volume = mt5.symbol_info(symbol).volume_step

    if raw_volume < min_volume:
        return min_volume
    elif raw_volume > max_volume:
        return max_volume
    else:
        return round(raw_volume / step_volume) * step_volume

# Run the trading loop
while True:
    # Fetch live data
    rates = mt5.copy_rates_from_pos("BTCUSD", mt5.TIMEFRAME_M1, 0, 100)
    rates_frame = pd.DataFrame(rates)
    rates_frame['time'] = pd.to_datetime(rates_frame['time'], unit='s')
    rates_frame.set_index('time', inplace=True)

    # Feature engineering
    rates_frame['Change_Open_Close'] = ((rates_frame['close'] - rates_frame['open']) / rates_frame['open']) * 100
    rates_frame['Change_High_Low'] = ((rates_frame['high'] - rates_frame['low']) / rates_frame['high']) * 100
    rates_frame['Profit_Between_Time_Series'] = rates_frame['Change_Open_Close'].diff().fillna(0)
    rates_frame['Buy_Signal'] = (rates_frame['Profit_Between_Time_Series'] > 0.165).astype(int)
    rates_frame['Sell_Signal'] = rates_frame['Buy_Signal'].shift(-1).fillna(0).astype(int)

    # Prepare features for model prediction
    features = rates_frame.drop(columns=['Buy_Signal', 'Sell_Signal']).values
    scaler = StandardScaler()
    scaled_features = scaler.fit_transform(features)

    # Predicting buy signals
    with torch.no_grad():
        inputs = torch.tensor(scaled_features, dtype=torch.float32).to(device)
        outputs = model(inputs.unsqueeze(1))
        predicted_signals = torch.argmax(outputs, dim=1).cpu().numpy()

    rates_frame['Predicted_Buy_Signal'] = predicted_signals

    # Execute trades based on predictions
    current_price = rates_frame['close'].iloc[-1]
    date_time = datetime.datetime.now()
    risk_per_trade = capital * 0.01  # Risk 1% of current capital per trade

    if rates_frame['Predicted_Buy_Signal'].iloc[-1] == 1 and positions == 0:
        # Enter position
        raw_volume = risk_per_trade / current_price
        validated_volume = validate_volume(raw_volume, "BTCUSD")

        positions = validated_volume
        entry_price = current_price
        stop_loss_price = entry_price - (entry_price * stop_loss_percentage / 100)
        log_entry = {
            'time': date_time,
            'action': 'enter',
            'price': entry_price,
            'positions': positions,
            'capital': capital,
            'profit_percentage': None,
            'profit': None
        }
        trade_log_df = pd.concat([trade_log_df, pd.DataFrame([log_entry])], ignore_index=True)
        with open(log_file_path, "a") as log_file:
            log_file.write(f"Entered position at time {date_time}, price: {entry_price}, positions: {positions}, capital: {capital}\n")

    if positions != 0:
        profit_percentage = (current_price - entry_price) / entry_price * 100

        if profit_percentage >= profit_cap_percentage or current_price <= stop_loss_price:
            # Exit position due to reaching profit cap or stop loss
            profit = positions * (current_price - entry_price) * leverage
            capital += profit

            if current_price <= stop_loss_price:
                # Reduce capital by the risked amount
                capital -= risk_per_trade

            log_exit = {
                'time': date_time,
                'action': 'exit',
                'price': current_price,
                'positions': positions,
                'capital': capital,
                'profit_percentage': profit_percentage,
                'profit': profit
            }
            trade_log_df = pd.concat([trade_log_df, pd.DataFrame([log_exit])], ignore_index=True)
            with open(log_file_path, "a") as log_file:
                log_file.write(f"Exited position at time {date_time}, price: {current_price}, profit_percentage: {profit_percentage}, profit: {profit}, capital: {capital}\n")

            # Reset positions
            positions = 0
            entry_price = None

    # Print details of each iteration
    iteration_log = {
        'time': date_time,
        'price': current_price,
        'positions': positions,
        'capital': capital
    }
    iteration_log_df = pd.concat([iteration_log_df, pd.DataFrame([iteration_log])], ignore_index=True)
    print(f"Iteration at time {date_time}, current price: {current_price}, positions: {positions}, capital: {capital}")
    with open(log_file_path, "a") as log_file:
        log_file.write(f"Iteration at time {date_time}, current price: {current_price}, positions: {positions}, capital: {capital}\n")

    # Save logs to CSV files
    trade_log_df.to_csv(log_csv_path, index=False)
    iteration_log_df.to_csv(iteration_csv_path, index=False)

    # Wait before the next iteration (e.g., 1 minute)
    time.sleep(60)
